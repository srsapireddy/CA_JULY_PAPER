# %%
# Imnporting Libraries
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf

# Custom activation function
from keras.layers import Activation
from keras import backend as k
import tensorflow as tf
from tensorflow import keras
import keras.utils as generic_utils
import tensorflow.python.keras.utils as generic_utils
from tensorflow.keras.utils import get_custom_objects


@tf.function
def custom_activation(x):
  #def f1(): return k.tf.add(0.001,k.tf.add(x,7.5))
  def f3(): return k.tf.add(0.1935,k.tf.multiply(tf.cast(x, tf.float32),0.047))
  def f5(): return k.tf.add(0.3435,k.tf.multiply(tf.cast(x, tf.float32),0.107))
  def f7(): return k.tf.add(0.5,k.tf.multiply(tf.cast(x, tf.float32),0.231))
  def f9(): return k.tf.add(0.8065,k.tf.multiply(tf.cast(x, tf.float32),0.047))
  def f11(): return k.tf.add(0.908,k.tf.multiply(tf.cast(x, tf.float32),0.018))
  def f12(): return k.tf.ones([1,1],tf.float32)

  def f10(): return k.tf.where(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), 3), tf.less(tf.cast(x, tf.float32), 4)),x=f11(),y=f12())
  def f8(): return k.tf.where(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), 2), tf.less(tf.cast(x, tf.float32), 3)),x=f9(),y=f10())
  def f6(): return k.tf.where(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), -2), tf.less(tf.cast(x, tf.float32), 2)),x=f7(),y=f8())
  def f4(): return k.tf.where(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), -3), tf.less(tf.cast(x, tf.float32), -2)),x=f5(),y=f6())
  def f2(): return k.tf.where(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), -4), tf.less(tf.cast(x, tf.float32), -3)),x=f3(),y=f4())


  r = tf.where(
         condition=(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), -10), tf.less(tf.cast(x, tf.float32), -4))),
         x=k.tf.add(0.0085,k.tf.multiply(tf.cast(x, tf.float32),0.001)),
         y=f2()
     )

  return r

# 0
# 0.002 + 0.001(x+6.25) -> 0.00825+0.001x
# 0.023 + 0.007(x+3.75) -> 0.4925+0.007x
# 0.245 + 0.076(x+1.125) -> 0.3305+0.076x
# 0.755 + 0.207(x-1.125) -> 0.5222-0.207x
# 0.977 + 0.099(x-3.75) -> 0.6058-0.099x
# 0.998 + 0.012(x-6.25) -> 0.923-0.012x
# 1.0 + 0.001(x-8.75) -> 0.99125-0.001x

# k.tf.zeros([1,1], tf.float32)
"""
  r = K.tf.where(
         condition=(K.tf.logical_and(K.tf.greater(x, -10), K.tf.less(x, -5))),
         x=K.tf.add(0.001,K.tf.add(x,7.5)),
         y=f2()
     )
"""
#tf.logical_or((tf.logical_and(tf.greater(x, -10), tf.less(x, -5))), (tf.logical_and(tf.greater(x, -5), tf.less(x, 5)) )


    #def f1(): return tf.add(0.5,tf.multi(0.099,x))

    # return tf.where(
    #     condition=tf.logical_or((tf.logical_and(tf.greater(x, -10), tf.less(x, -5))), (tf.logical_and(tf.greater(x, -5), tf.less(x, 5)) )),
    #     x=tf.add(0.001,tf.add(x,7.5)),
    #     y=tf.add(0.5,tf.multiply(0.099,x))
    # )

"""
  x =tf.dtypes.cast(x, tf.int32)
  if (x > -10 & x < -5):
    y = 0.001 + 0.015*(x+7.5);
  if (x > -5 & x < 5):
    y = 0.5 + 0.099*x;
  if x > 5:
    y = 0.999;
  return y
"""
"""
loss = tf.where(
        condition=tf.logical_or((tf.logical_and(tf.greater(y_true, 0.0), tf.greater(y_pred, y_true))), (tf.logical_and(tf.less(y_true, 0.0), tf.less(y_pred, y_true)))),
        x=loss * penalty / 5,
        y=loss * penalty / 10
    )
"""
"""
# working
# tf.where(tf.less(x, 0), tf.add(0.5,tf.multiply(0.099,x)) ,tf.add(0.5,tf.multiply(0.099,x)))
"""
# tf.where(tf.less(x, 0), true_fn=lambda: tf.add(0.5,tf.multiply(0.099,x)), false_fn=lambda: tf.add(0.5,tf.multiply(0.099,x)))
# tf.cond(tf.logical_and(tf.less(x,-10),tf.greater(x,-5))):
"""
    if x > -5 and x < 5:
        return tf.add(0.5,tf.multi(0.099,x))
    if x > 5:
        return 0.999
"""
get_custom_objects().update({'custom_activation': Activation(custom_activation)})
"""
# Usage
model = Sequential()
model.add(Dense(32, input_dim=784))
model.add(Activation(custom_activation, name='SpecialActivation'))
print(model.summary())
"""
# Out:
# "\n# Usage\nmodel = Sequential()\nmodel.add(Dense(32, input_dim=784))\nmodel.add(Activation(custom_activation, name='SpecialActivation'))\nprint(model.summary())\n"

# %%
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

import tensorflow
tensorflow.random.set_seed(22)

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# from sparse label to categorical
num_labels = len(np.unique(y_train))
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# reshape and normalize input images
image_size = x_train.shape[1]
x_train = np.reshape(x_train,[-1, image_size, image_size, 1])
x_test = np.reshape(x_test,[-1, image_size, image_size, 1])
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# network parameters
input_shape = (image_size, image_size, 1)
batch_size = 128
kernel_size = 3
filters = 64
dropout = 0.3

# use functional API to build cnn layers
inputs = Input(shape=input_shape)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(inputs)

y = MaxPooling2D()(y)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(y)

y = MaxPooling2D()(y)
# y = Conv2D(filters=filters,
#            kernel_size=kernel_size,
#            activation='relu')(y)
# image to vector before connecting to dense layer
y = Flatten()(y)
# dropout regularization
#y = Dropout(dropout)(y)
outputs = Dense(num_labels, activation='softmax')(y)



# build the model by supplying inputs/outputs
model = Model(inputs=inputs, outputs=outputs)
# network model in text
model.summary()
# Retrieve the config
import tensorflow
from tensorflow.keras.optimizers import Adam
# classifier loss, Adam optimizer, classifier accuracy
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.0001),
              metrics=['accuracy'])

# train the model with input images and labels
model.fit(x_train,
          y_train,
          validation_data=(x_test, y_test),
          epochs=50,
          batch_size=batch_size)

# model accuracy on test dataset
score = model.evaluate(x_test,
                       y_test,
                       batch_size=batch_size,
                       verbose=0)
print("\nTest accuracy: %.1f%%" % (100.0 * score[1]))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 10)                16010
#
# =================================================================
# Total params: 53,578
# Trainable params: 53,578
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 19s 20ms/step - loss: 2.2989 - accuracy: 0.1225 - val_loss: 2.2778 - val_accuracy: 0.1609
# Epoch 2/50
# 469/469 [==============================] - 9s 19ms/step - loss: 2.1751 - accuracy: 0.3330 - val_loss: 1.8900 - val_accuracy: 0.5452
# Epoch 3/50
# 469/469 [==============================] - 9s 19ms/step - loss: 1.2625 - accuracy: 0.7373 - val_loss: 0.7759 - val_accuracy: 0.8162
# Epoch 4/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.6425 - accuracy: 0.8341 - val_loss: 0.5234 - val_accuracy: 0.8595
# Epoch 5/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.4841 - accuracy: 0.8680 - val_loss: 0.4194 - val_accuracy: 0.8840
# Epoch 6/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.4059 - accuracy: 0.8856 - val_loss: 0.3602 - val_accuracy: 0.8973
# Epoch 7/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.3528 - accuracy: 0.9003 - val_loss: 0.3140 - val_accuracy: 0.9102
# Epoch 8/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.3104 - accuracy: 0.9122 - val_loss: 0.2790 - val_accuracy: 0.9199
# Epoch 9/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.2752 - accuracy: 0.9225 - val_loss: 0.2449 - val_accuracy: 0.9306
# Epoch 10/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.2460 - accuracy: 0.9309 - val_loss: 0.2210 - val_accuracy: 0.9387
# Epoch 11/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.2217 - accuracy: 0.9380 - val_loss: 0.1983 - val_accuracy: 0.9427
# Epoch 12/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1996 - accuracy: 0.9439 - val_loss: 0.1788 - val_accuracy: 0.9478
# Epoch 13/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1808 - accuracy: 0.9494 - val_loss: 0.1597 - val_accuracy: 0.9558
# Epoch 14/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1648 - accuracy: 0.9537 - val_loss: 0.1458 - val_accuracy: 0.9598
# Epoch 15/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1510 - accuracy: 0.9574 - val_loss: 0.1349 - val_accuracy: 0.9630
# Epoch 16/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1397 - accuracy: 0.9607 - val_loss: 0.1240 - val_accuracy: 0.9653
# Epoch 17/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1297 - accuracy: 0.9633 - val_loss: 0.1160 - val_accuracy: 0.9675
# Epoch 18/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.1213 - accuracy: 0.9658 - val_loss: 0.1093 - val_accuracy: 0.9689
# Epoch 19/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1144 - accuracy: 0.9678 - val_loss: 0.1018 - val_accuracy: 0.9704
# Epoch 20/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1076 - accuracy: 0.9693 - val_loss: 0.0961 - val_accuracy: 0.9725
# Epoch 21/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.1021 - accuracy: 0.9708 - val_loss: 0.0928 - val_accuracy: 0.9730
# Epoch 22/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0971 - accuracy: 0.9723 - val_loss: 0.0880 - val_accuracy: 0.9735
# Epoch 23/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0929 - accuracy: 0.9732 - val_loss: 0.0854 - val_accuracy: 0.9752
# Epoch 24/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0898 - accuracy: 0.9739 - val_loss: 0.0829 - val_accuracy: 0.9753
# Epoch 25/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0866 - accuracy: 0.9750 - val_loss: 0.0791 - val_accuracy: 0.9770
# Epoch 26/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0836 - accuracy: 0.9756 - val_loss: 0.0767 - val_accuracy: 0.9779
# Epoch 27/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0809 - accuracy: 0.9766 - val_loss: 0.0749 - val_accuracy: 0.9770
# Epoch 28/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0785 - accuracy: 0.9775 - val_loss: 0.0727 - val_accuracy: 0.9788
# Epoch 29/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0764 - accuracy: 0.9776 - val_loss: 0.0705 - val_accuracy: 0.9796
# Epoch 30/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0743 - accuracy: 0.9783 - val_loss: 0.0684 - val_accuracy: 0.9800
# Epoch 31/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0730 - accuracy: 0.9785 - val_loss: 0.0675 - val_accuracy: 0.9795
# Epoch 32/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0714 - accuracy: 0.9791 - val_loss: 0.0669 - val_accuracy: 0.9795
# Epoch 33/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0696 - accuracy: 0.9794 - val_loss: 0.0642 - val_accuracy: 0.9804
# Epoch 34/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0684 - accuracy: 0.9795 - val_loss: 0.0651 - val_accuracy: 0.9802
# Epoch 35/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0672 - accuracy: 0.9801 - val_loss: 0.0635 - val_accuracy: 0.9807
# Epoch 36/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0657 - accuracy: 0.9805 - val_loss: 0.0635 - val_accuracy: 0.9800
# Epoch 37/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0644 - accuracy: 0.9805 - val_loss: 0.0618 - val_accuracy: 0.9807
# Epoch 38/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0632 - accuracy: 0.9808 - val_loss: 0.0619 - val_accuracy: 0.9801
# Epoch 39/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0624 - accuracy: 0.9814 - val_loss: 0.0603 - val_accuracy: 0.9809
# Epoch 40/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0616 - accuracy: 0.9813 - val_loss: 0.0605 - val_accuracy: 0.9813
# Epoch 41/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0606 - accuracy: 0.9818 - val_loss: 0.0599 - val_accuracy: 0.9817
# Epoch 42/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0597 - accuracy: 0.9822 - val_loss: 0.0580 - val_accuracy: 0.9828
# Epoch 43/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0592 - accuracy: 0.9819 - val_loss: 0.0600 - val_accuracy: 0.9806
# Epoch 44/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0586 - accuracy: 0.9822 - val_loss: 0.0570 - val_accuracy: 0.9819
# Epoch 45/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0578 - accuracy: 0.9824 - val_loss: 0.0568 - val_accuracy: 0.9832
# Epoch 46/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0572 - accuracy: 0.9826 - val_loss: 0.0562 - val_accuracy: 0.9821
# Epoch 47/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0565 - accuracy: 0.9827 - val_loss: 0.0560 - val_accuracy: 0.9820
# Epoch 48/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0555 - accuracy: 0.9833 - val_loss: 0.0562 - val_accuracy: 0.9820
# Epoch 49/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0551 - accuracy: 0.9831 - val_loss: 0.0553 - val_accuracy: 0.9832
# Epoch 50/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.0540 - accuracy: 0.9837 - val_loss: 0.0543 - val_accuracy: 0.9831
#
# Test accuracy: 98.3%

# %%
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

import tensorflow
tensorflow.random.set_seed(22)

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# from sparse label to categorical
num_labels = len(np.unique(y_train))
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# reshape and normalize input images
image_size = x_train.shape[1]
x_train = np.reshape(x_train,[-1, image_size, image_size, 1])
x_test = np.reshape(x_test,[-1, image_size, image_size, 1])
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# network parameters
input_shape = (image_size, image_size, 1)
batch_size = 128
kernel_size = 3
filters = 64
dropout = 0.3

# use functional API to build cnn layers
inputs = Input(shape=input_shape)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='sigmoid')(inputs)

y = MaxPooling2D()(y)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='sigmoid')(y)

y = MaxPooling2D()(y)
# y = Conv2D(filters=filters,
#            kernel_size=kernel_size,
#            activation='relu')(y)
# image to vector before connecting to dense layer
y = Flatten()(y)
# dropout regularization
#y = Dropout(dropout)(y)
outputs = Dense(num_labels, activation='softmax')(y)



# build the model by supplying inputs/outputs
model = Model(inputs=inputs, outputs=outputs)
# network model in text
model.summary()
# Retrieve the config
import tensorflow
from tensorflow.keras.optimizers import Adam
# classifier loss, Adam optimizer, classifier accuracy
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.0001),
              metrics=['accuracy'])

# train the model with input images and labels
model.fit(x_train,
          y_train,
          validation_data=(x_test, y_test),
          epochs=50,
          batch_size=batch_size)

# model accuracy on test dataset
score = model.evaluate(x_test,
                       y_test,
                       batch_size=batch_size,
                       verbose=0)
print("\nTest accuracy: %.1f%%" % (100.0 * score[1]))
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 26, 26, 64)        640
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1600)              0
#
#  dense_1 (Dense)             (None, 10)                16010
#
# =================================================================
# Total params: 53,578
# Trainable params: 53,578
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 4s 6ms/step - loss: 2.3024 - accuracy: 0.1180 - val_loss: 2.2814 - val_accuracy: 0.1945
# Epoch 2/50
# 469/469 [==============================] - 3s 6ms/step - loss: 2.1921 - accuracy: 0.2922 - val_loss: 1.9426 - val_accuracy: 0.4659
# Epoch 3/50
# 469/469 [==============================] - 3s 6ms/step - loss: 1.3650 - accuracy: 0.7130 - val_loss: 0.8701 - val_accuracy: 0.8101
# Epoch 4/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.7061 - accuracy: 0.8256 - val_loss: 0.5651 - val_accuracy: 0.8509
# Epoch 5/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.5165 - accuracy: 0.8623 - val_loss: 0.4429 - val_accuracy: 0.8815
# Epoch 6/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4267 - accuracy: 0.8818 - val_loss: 0.3769 - val_accuracy: 0.8947
# Epoch 7/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3690 - accuracy: 0.8971 - val_loss: 0.3295 - val_accuracy: 0.9086
# Epoch 8/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3259 - accuracy: 0.9085 - val_loss: 0.2953 - val_accuracy: 0.9165
# Epoch 9/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2912 - accuracy: 0.9181 - val_loss: 0.2608 - val_accuracy: 0.9264
# Epoch 10/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2618 - accuracy: 0.9262 - val_loss: 0.2370 - val_accuracy: 0.9349
# Epoch 11/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2371 - accuracy: 0.9337 - val_loss: 0.2142 - val_accuracy: 0.9392
# Epoch 12/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2154 - accuracy: 0.9397 - val_loss: 0.1957 - val_accuracy: 0.9448
# Epoch 13/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1969 - accuracy: 0.9446 - val_loss: 0.1767 - val_accuracy: 0.9511
# Epoch 14/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1810 - accuracy: 0.9490 - val_loss: 0.1621 - val_accuracy: 0.9537
# Epoch 15/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1671 - accuracy: 0.9532 - val_loss: 0.1520 - val_accuracy: 0.9566
# Epoch 16/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1554 - accuracy: 0.9568 - val_loss: 0.1400 - val_accuracy: 0.9599
# Epoch 17/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1450 - accuracy: 0.9593 - val_loss: 0.1320 - val_accuracy: 0.9631
# Epoch 18/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1360 - accuracy: 0.9622 - val_loss: 0.1233 - val_accuracy: 0.9654
# Epoch 19/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1285 - accuracy: 0.9644 - val_loss: 0.1167 - val_accuracy: 0.9673
# Epoch 20/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1216 - accuracy: 0.9660 - val_loss: 0.1101 - val_accuracy: 0.9694
# Epoch 21/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1157 - accuracy: 0.9675 - val_loss: 0.1056 - val_accuracy: 0.9701
# Epoch 22/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1102 - accuracy: 0.9694 - val_loss: 0.1015 - val_accuracy: 0.9705
# Epoch 23/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1054 - accuracy: 0.9699 - val_loss: 0.0973 - val_accuracy: 0.9717
# Epoch 24/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1013 - accuracy: 0.9717 - val_loss: 0.0942 - val_accuracy: 0.9725
# Epoch 25/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0975 - accuracy: 0.9723 - val_loss: 0.0900 - val_accuracy: 0.9740
# Epoch 26/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0940 - accuracy: 0.9732 - val_loss: 0.0868 - val_accuracy: 0.9752
# Epoch 27/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0906 - accuracy: 0.9748 - val_loss: 0.0848 - val_accuracy: 0.9752
# Epoch 28/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0878 - accuracy: 0.9749 - val_loss: 0.0817 - val_accuracy: 0.9759
# Epoch 29/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0852 - accuracy: 0.9755 - val_loss: 0.0791 - val_accuracy: 0.9774
# Epoch 30/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0828 - accuracy: 0.9762 - val_loss: 0.0763 - val_accuracy: 0.9779
# Epoch 31/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0806 - accuracy: 0.9771 - val_loss: 0.0744 - val_accuracy: 0.9787
# Epoch 32/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0783 - accuracy: 0.9778 - val_loss: 0.0732 - val_accuracy: 0.9780
# Epoch 33/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0762 - accuracy: 0.9778 - val_loss: 0.0709 - val_accuracy: 0.9790
# Epoch 34/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0744 - accuracy: 0.9787 - val_loss: 0.0703 - val_accuracy: 0.9794
# Epoch 35/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0729 - accuracy: 0.9788 - val_loss: 0.0681 - val_accuracy: 0.9798
# Epoch 36/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0709 - accuracy: 0.9795 - val_loss: 0.0693 - val_accuracy: 0.9790
# Epoch 37/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0695 - accuracy: 0.9798 - val_loss: 0.0659 - val_accuracy: 0.9800
# Epoch 38/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0681 - accuracy: 0.9801 - val_loss: 0.0653 - val_accuracy: 0.9804
# Epoch 39/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0667 - accuracy: 0.9806 - val_loss: 0.0634 - val_accuracy: 0.9804
# Epoch 40/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0654 - accuracy: 0.9810 - val_loss: 0.0629 - val_accuracy: 0.9818
# Epoch 41/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0641 - accuracy: 0.9816 - val_loss: 0.0617 - val_accuracy: 0.9808
# Epoch 42/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0627 - accuracy: 0.9819 - val_loss: 0.0602 - val_accuracy: 0.9820
# Epoch 43/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0616 - accuracy: 0.9822 - val_loss: 0.0609 - val_accuracy: 0.9825
# Epoch 44/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0607 - accuracy: 0.9822 - val_loss: 0.0585 - val_accuracy: 0.9822
# Epoch 45/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0595 - accuracy: 0.9830 - val_loss: 0.0579 - val_accuracy: 0.9830
# Epoch 46/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0586 - accuracy: 0.9828 - val_loss: 0.0566 - val_accuracy: 0.9835
# Epoch 47/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0576 - accuracy: 0.9834 - val_loss: 0.0557 - val_accuracy: 0.9838
# Epoch 48/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0566 - accuracy: 0.9840 - val_loss: 0.0556 - val_accuracy: 0.9831
# Epoch 49/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0557 - accuracy: 0.9840 - val_loss: 0.0543 - val_accuracy: 0.9834
# Epoch 50/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0547 - accuracy: 0.9844 - val_loss: 0.0537 - val_accuracy: 0.9839
#
# Test accuracy: 98.4%
