# %% [markdown]
# **ORIGINAL TEST**

# %%
# Imnporting Libraries
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf
import numpy as np
# Custom activation function
from keras.layers import Activation
from keras import backend as K
import tensorflow as tf
from tensorflow import keras
import keras.utils as generic_utils
import tensorflow.python.keras.utils as generic_utils
from tensorflow.keras.utils import get_custom_objects


@tf.function
def custom_activation(x):

  #def f1(): return 0.001
  def f3(): return K.tf.add(0.5,K.tf.multiply(tf.cast(x, tf.float32),0.231))
  def f4(): return K.tf.add(0.986,K.tf.multiply(0.002,tf.cast(x, tf.float32)))
  def f2(): return K.tf.where(K.tf.logical_and(K.tf.greater(tf.cast(x, tf.float32), -2.5), K.tf.less(tf.cast(x, tf.float32), 2.5)),x=f3(),y=f4())



  r = K.tf.where(
         condition=(K.tf.logical_and(K.tf.greater(tf.cast(x, tf.float32), -10), K.tf.less(tf.cast(x, tf.float32), -2.5))),
         x=K.tf.add(0.026,K.tf.multiply(0.004,tf.cast(x, tf.float32))),
         y=f2())

  return r


get_custom_objects().update({'custom_activation': Activation(custom_activation)})

# %%
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

import tensorflow
tensorflow.random.set_seed(22)

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# from sparse label to categorical
num_labels = len(np.unique(y_train))
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# reshape and normalize input images
image_size = x_train.shape[1]
x_train = np.reshape(x_train,[-1, image_size, image_size, 1])
x_test = np.reshape(x_test,[-1, image_size, image_size, 1])
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# network parameters
input_shape = (image_size, image_size, 1)
batch_size = 128
kernel_size = 3
filters = 64
dropout = 0.3

# use functional API to build cnn layers
inputs = Input(shape=input_shape)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(inputs)

y = MaxPooling2D()(y)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(y)

y = MaxPooling2D()(y)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(y)

y = MaxPooling2D()(y)
# y = Conv2D(filters=filters,
#            kernel_size=kernel_size,
#            activation='relu')(y)
# image to vector before connecting to dense layer
y = Flatten()(y)
# dropout regularization
#y = Dropout(dropout)(y)
outputs = Dense(num_labels, activation='softmax')(y)



# build the model by supplying inputs/outputs
model = Model(inputs=inputs, outputs=outputs)
# network model in text
model.summary()
# Retrieve the config
import tensorflow
from tensorflow.keras.optimizers import Adam
# classifier loss, Adam optimizer, classifier accuracy
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.0001),
              metrics=['accuracy'])

import time

start_time = time.time()

# train the model with input images and labels
model.fit(x_train,
          y_train,
          validation_data=(x_test, y_test),
          epochs=50,
          batch_size=batch_size)

end_time = time.time()
execution_time = end_time - start_time

# model accuracy on test dataset
score = model.evaluate(x_test,
                       y_test,
                       batch_size=batch_size,
                       verbose=0)
print("\nTest accuracy: %.1f%%" % (100.0 * score[1]))
print("Execution time: {:.2f} seconds".format(execution_time))
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 64)          36928
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 10)                650
#
# =================================================================
# Total params: 75,146
# Trainable params: 75,146
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 7s 6ms/step - loss: 2.3026 - accuracy: 0.1120 - val_loss: 2.2985 - val_accuracy: 0.2094
# Epoch 2/50
# 469/469 [==============================] - 2s 5ms/step - loss: 2.2846 - accuracy: 0.1667 - val_loss: 2.2450 - val_accuracy: 0.2894
# Epoch 3/50
# 469/469 [==============================] - 2s 5ms/step - loss: 1.9702 - accuracy: 0.4852 - val_loss: 1.5011 - val_accuracy: 0.6615
# Epoch 4/50
# 469/469 [==============================] - 2s 5ms/step - loss: 1.2306 - accuracy: 0.7042 - val_loss: 0.9987 - val_accuracy: 0.7656
# Epoch 5/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.9100 - accuracy: 0.7843 - val_loss: 0.7717 - val_accuracy: 0.8269
# Epoch 6/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.7218 - accuracy: 0.8341 - val_loss: 0.6170 - val_accuracy: 0.8629
# Epoch 7/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.5914 - accuracy: 0.8641 - val_loss: 0.5129 - val_accuracy: 0.8822
# Epoch 8/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4989 - accuracy: 0.8842 - val_loss: 0.4384 - val_accuracy: 0.8986
# Epoch 9/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4318 - accuracy: 0.8977 - val_loss: 0.3819 - val_accuracy: 0.9094
# Epoch 10/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3811 - accuracy: 0.9076 - val_loss: 0.3397 - val_accuracy: 0.9198
# Epoch 11/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3420 - accuracy: 0.9154 - val_loss: 0.3067 - val_accuracy: 0.9230
# Epoch 12/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3105 - accuracy: 0.9216 - val_loss: 0.2800 - val_accuracy: 0.9291
# Epoch 13/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2847 - accuracy: 0.9266 - val_loss: 0.2555 - val_accuracy: 0.9327
# Epoch 14/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2626 - accuracy: 0.9317 - val_loss: 0.2372 - val_accuracy: 0.9366
# Epoch 15/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2443 - accuracy: 0.9351 - val_loss: 0.2238 - val_accuracy: 0.9399
# Epoch 16/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2290 - accuracy: 0.9385 - val_loss: 0.2091 - val_accuracy: 0.9424
# Epoch 17/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2151 - accuracy: 0.9420 - val_loss: 0.1995 - val_accuracy: 0.9429
# Epoch 18/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2034 - accuracy: 0.9450 - val_loss: 0.1883 - val_accuracy: 0.9477
# Epoch 19/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1936 - accuracy: 0.9469 - val_loss: 0.1796 - val_accuracy: 0.9486
# Epoch 20/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1843 - accuracy: 0.9491 - val_loss: 0.1714 - val_accuracy: 0.9515
# Epoch 21/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1763 - accuracy: 0.9508 - val_loss: 0.1654 - val_accuracy: 0.9517
# Epoch 22/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1686 - accuracy: 0.9533 - val_loss: 0.1597 - val_accuracy: 0.9538
# Epoch 23/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1619 - accuracy: 0.9548 - val_loss: 0.1533 - val_accuracy: 0.9544
# Epoch 24/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1558 - accuracy: 0.9569 - val_loss: 0.1493 - val_accuracy: 0.9552
# Epoch 25/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1503 - accuracy: 0.9579 - val_loss: 0.1423 - val_accuracy: 0.9582
# Epoch 26/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1454 - accuracy: 0.9593 - val_loss: 0.1391 - val_accuracy: 0.9592
# Epoch 27/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1403 - accuracy: 0.9609 - val_loss: 0.1345 - val_accuracy: 0.9605
# Epoch 28/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1360 - accuracy: 0.9620 - val_loss: 0.1316 - val_accuracy: 0.9609
# Epoch 29/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1319 - accuracy: 0.9628 - val_loss: 0.1294 - val_accuracy: 0.9613
# Epoch 30/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1280 - accuracy: 0.9639 - val_loss: 0.1240 - val_accuracy: 0.9624
# Epoch 31/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1243 - accuracy: 0.9655 - val_loss: 0.1218 - val_accuracy: 0.9635
# Epoch 32/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1209 - accuracy: 0.9659 - val_loss: 0.1189 - val_accuracy: 0.9639
# Epoch 33/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1177 - accuracy: 0.9675 - val_loss: 0.1144 - val_accuracy: 0.9652
# Epoch 34/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1151 - accuracy: 0.9678 - val_loss: 0.1136 - val_accuracy: 0.9654
# Epoch 35/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1123 - accuracy: 0.9688 - val_loss: 0.1106 - val_accuracy: 0.9663
# Epoch 36/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1089 - accuracy: 0.9694 - val_loss: 0.1089 - val_accuracy: 0.9679
# Epoch 37/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1068 - accuracy: 0.9705 - val_loss: 0.1070 - val_accuracy: 0.9671
# Epoch 38/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1048 - accuracy: 0.9704 - val_loss: 0.1055 - val_accuracy: 0.9682
# Epoch 39/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1024 - accuracy: 0.9713 - val_loss: 0.1030 - val_accuracy: 0.9682
# Epoch 40/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1003 - accuracy: 0.9719 - val_loss: 0.1019 - val_accuracy: 0.9690
# Epoch 41/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0980 - accuracy: 0.9723 - val_loss: 0.0988 - val_accuracy: 0.9699
# Epoch 42/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0959 - accuracy: 0.9723 - val_loss: 0.0982 - val_accuracy: 0.9700
# Epoch 43/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0938 - accuracy: 0.9738 - val_loss: 0.0963 - val_accuracy: 0.9710
# Epoch 44/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0921 - accuracy: 0.9739 - val_loss: 0.0944 - val_accuracy: 0.9708
# Epoch 45/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0906 - accuracy: 0.9739 - val_loss: 0.0940 - val_accuracy: 0.9707
# Epoch 46/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0888 - accuracy: 0.9748 - val_loss: 0.0920 - val_accuracy: 0.9715
# Epoch 47/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0874 - accuracy: 0.9750 - val_loss: 0.0906 - val_accuracy: 0.9726
# Epoch 48/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0856 - accuracy: 0.9758 - val_loss: 0.0887 - val_accuracy: 0.9729
# Epoch 49/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0843 - accuracy: 0.9760 - val_loss: 0.0884 - val_accuracy: 0.9740
# Epoch 50/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0830 - accuracy: 0.9768 - val_loss: 0.0875 - val_accuracy: 0.9743
#
# Test accuracy: 97.4%
# Execution time: 118.76 seconds

# %% [markdown]
# **TEST WITH SINGLE SLOPE AT 0**

# %%
# Imnporting Libraries
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf
import numpy as np
# Custom activation function
from keras.layers import Activation
from keras import backend as K
import tensorflow as tf
from tensorflow import keras
import keras.utils as generic_utils
import tensorflow.python.keras.utils as generic_utils
from tensorflow.keras.utils import get_custom_objects


@tf.function
def custom_activation(x):

  #def f1(): return 0.001
  def f3(): return K.tf.add(0.5,K.tf.multiply(tf.cast(x, tf.float32),0.231))
  def f4(): return K.tf.add(1.0,K.tf.multiply(0.0,tf.cast(x, tf.float32)))
  def f2(): return K.tf.where(K.tf.logical_and(K.tf.greater(tf.cast(x, tf.float32), -2.5), K.tf.less(tf.cast(x, tf.float32), 2.5)),x=f3(),y=f4())



  r = K.tf.where(
         condition=(K.tf.logical_and(K.tf.greater(tf.cast(x, tf.float32), -10), K.tf.less(tf.cast(x, tf.float32), -2.5))),
         x=K.tf.add(0.0,K.tf.multiply(0.0,tf.cast(x, tf.float32))),
         y=f2())

  return r


get_custom_objects().update({'custom_activation': Activation(custom_activation)})

# %%
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

import tensorflow
tensorflow.random.set_seed(22)

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# from sparse label to categorical
num_labels = len(np.unique(y_train))
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# reshape and normalize input images
image_size = x_train.shape[1]
x_train = np.reshape(x_train,[-1, image_size, image_size, 1])
x_test = np.reshape(x_test,[-1, image_size, image_size, 1])
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# network parameters
input_shape = (image_size, image_size, 1)
batch_size = 128
kernel_size = 3
filters = 64
dropout = 0.3

# use functional API to build cnn layers
inputs = Input(shape=input_shape)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(inputs)

y = MaxPooling2D()(y)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(y)

y = MaxPooling2D()(y)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(y)

y = MaxPooling2D()(y)
# y = Conv2D(filters=filters,
#            kernel_size=kernel_size,
#            activation='relu')(y)
# image to vector before connecting to dense layer
y = Flatten()(y)
# dropout regularization
#y = Dropout(dropout)(y)
outputs = Dense(num_labels, activation='softmax')(y)



# build the model by supplying inputs/outputs
model = Model(inputs=inputs, outputs=outputs)
# network model in text
model.summary()
# Retrieve the config
import tensorflow
from tensorflow.keras.optimizers import Adam
# classifier loss, Adam optimizer, classifier accuracy
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.0001),
              metrics=['accuracy'])

import time

start_time = time.time()


# train the model with input images and labels
model.fit(x_train,
          y_train,
          validation_data=(x_test, y_test),
          epochs=50,
          batch_size=batch_size)

end_time = time.time()
execution_time = end_time - start_time

# model accuracy on test dataset
score = model.evaluate(x_test,
                       y_test,
                       batch_size=batch_size,
                       verbose=0)
print("\nTest accuracy: %.1f%%" % (100.0 * score[1]))
print("Execution time: {:.2f} seconds".format(execution_time))
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_3 (Conv2D)           (None, 26, 26, 64)        640
#
#  max_pooling2d_3 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 64)          36928
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 75,146
# Trainable params: 75,146
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 4s 5ms/step - loss: 2.3041 - accuracy: 0.1108 - val_loss: 2.2988 - val_accuracy: 0.1135
# Epoch 2/50
# 469/469 [==============================] - 2s 5ms/step - loss: 2.2806 - accuracy: 0.1804 - val_loss: 2.2103 - val_accuracy: 0.2679
# Epoch 3/50
# 469/469 [==============================] - 2s 5ms/step - loss: 1.8444 - accuracy: 0.5229 - val_loss: 1.3637 - val_accuracy: 0.6801
# Epoch 4/50
# 469/469 [==============================] - 2s 5ms/step - loss: 1.1370 - accuracy: 0.7291 - val_loss: 0.9134 - val_accuracy: 0.7877
# Epoch 5/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.8246 - accuracy: 0.8092 - val_loss: 0.6915 - val_accuracy: 0.8421
# Epoch 6/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.6489 - accuracy: 0.8487 - val_loss: 0.5549 - val_accuracy: 0.8695
# Epoch 7/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.5351 - accuracy: 0.8745 - val_loss: 0.4665 - val_accuracy: 0.8877
# Epoch 8/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.4553 - accuracy: 0.8911 - val_loss: 0.4010 - val_accuracy: 0.9036
# Epoch 9/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3948 - accuracy: 0.9051 - val_loss: 0.3489 - val_accuracy: 0.9141
# Epoch 10/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3476 - accuracy: 0.9149 - val_loss: 0.3088 - val_accuracy: 0.9233
# Epoch 11/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.3110 - accuracy: 0.9227 - val_loss: 0.2780 - val_accuracy: 0.9298
# Epoch 12/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2816 - accuracy: 0.9289 - val_loss: 0.2538 - val_accuracy: 0.9338
# Epoch 13/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2586 - accuracy: 0.9341 - val_loss: 0.2317 - val_accuracy: 0.9379
# Epoch 14/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2393 - accuracy: 0.9370 - val_loss: 0.2157 - val_accuracy: 0.9423
# Epoch 15/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2231 - accuracy: 0.9408 - val_loss: 0.2036 - val_accuracy: 0.9448
# Epoch 16/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.2097 - accuracy: 0.9435 - val_loss: 0.1893 - val_accuracy: 0.9490
# Epoch 17/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1977 - accuracy: 0.9464 - val_loss: 0.1796 - val_accuracy: 0.9515
# Epoch 18/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1870 - accuracy: 0.9487 - val_loss: 0.1696 - val_accuracy: 0.9541
# Epoch 19/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1783 - accuracy: 0.9503 - val_loss: 0.1610 - val_accuracy: 0.9548
# Epoch 20/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1698 - accuracy: 0.9530 - val_loss: 0.1549 - val_accuracy: 0.9574
# Epoch 21/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1626 - accuracy: 0.9542 - val_loss: 0.1483 - val_accuracy: 0.9585
# Epoch 22/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1557 - accuracy: 0.9565 - val_loss: 0.1432 - val_accuracy: 0.9599
# Epoch 23/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1498 - accuracy: 0.9582 - val_loss: 0.1376 - val_accuracy: 0.9616
# Epoch 24/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1442 - accuracy: 0.9595 - val_loss: 0.1341 - val_accuracy: 0.9628
# Epoch 25/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1386 - accuracy: 0.9608 - val_loss: 0.1270 - val_accuracy: 0.9652
# Epoch 26/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1338 - accuracy: 0.9625 - val_loss: 0.1246 - val_accuracy: 0.9660
# Epoch 27/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1295 - accuracy: 0.9633 - val_loss: 0.1202 - val_accuracy: 0.9653
# Epoch 28/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1253 - accuracy: 0.9648 - val_loss: 0.1168 - val_accuracy: 0.9666
# Epoch 29/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1218 - accuracy: 0.9657 - val_loss: 0.1170 - val_accuracy: 0.9659
# Epoch 30/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1182 - accuracy: 0.9663 - val_loss: 0.1104 - val_accuracy: 0.9685
# Epoch 31/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1152 - accuracy: 0.9674 - val_loss: 0.1080 - val_accuracy: 0.9689
# Epoch 32/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1121 - accuracy: 0.9684 - val_loss: 0.1057 - val_accuracy: 0.9701
# Epoch 33/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1090 - accuracy: 0.9692 - val_loss: 0.1040 - val_accuracy: 0.9705
# Epoch 34/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1064 - accuracy: 0.9699 - val_loss: 0.1019 - val_accuracy: 0.9708
# Epoch 35/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1035 - accuracy: 0.9707 - val_loss: 0.1000 - val_accuracy: 0.9712
# Epoch 36/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1008 - accuracy: 0.9714 - val_loss: 0.0981 - val_accuracy: 0.9709
# Epoch 37/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0990 - accuracy: 0.9721 - val_loss: 0.0949 - val_accuracy: 0.9726
# Epoch 38/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0969 - accuracy: 0.9726 - val_loss: 0.0958 - val_accuracy: 0.9722
# Epoch 39/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0948 - accuracy: 0.9732 - val_loss: 0.0934 - val_accuracy: 0.9726
# Epoch 40/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0926 - accuracy: 0.9742 - val_loss: 0.0920 - val_accuracy: 0.9736
# Epoch 41/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0909 - accuracy: 0.9746 - val_loss: 0.0908 - val_accuracy: 0.9741
# Epoch 42/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0889 - accuracy: 0.9750 - val_loss: 0.0886 - val_accuracy: 0.9749
# Epoch 43/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0873 - accuracy: 0.9756 - val_loss: 0.0879 - val_accuracy: 0.9744
# Epoch 44/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0854 - accuracy: 0.9758 - val_loss: 0.0856 - val_accuracy: 0.9751
# Epoch 45/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0841 - accuracy: 0.9766 - val_loss: 0.0855 - val_accuracy: 0.9755
# Epoch 46/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0824 - accuracy: 0.9765 - val_loss: 0.0842 - val_accuracy: 0.9755
# Epoch 47/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0808 - accuracy: 0.9773 - val_loss: 0.0828 - val_accuracy: 0.9755
# Epoch 48/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0790 - accuracy: 0.9779 - val_loss: 0.0821 - val_accuracy: 0.9759
# Epoch 49/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0778 - accuracy: 0.9779 - val_loss: 0.0816 - val_accuracy: 0.9754
# Epoch 50/50
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0764 - accuracy: 0.9782 - val_loss: 0.0794 - val_accuracy: 0.9767
#
# Test accuracy: 97.7%
# Execution time: 113.62 seconds

# %% [markdown]
# **BASE FUNCTION**

# %%
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

import tensorflow
tensorflow.random.set_seed(22)

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# from sparse label to categorical
num_labels = len(np.unique(y_train))
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# reshape and normalize input images
image_size = x_train.shape[1]
x_train = np.reshape(x_train,[-1, image_size, image_size, 1])
x_test = np.reshape(x_test,[-1, image_size, image_size, 1])
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# network parameters
input_shape = (image_size, image_size, 1)
batch_size = 128
kernel_size = 3
filters = 64
dropout = 0.3

# use functional API to build cnn layers
inputs = Input(shape=input_shape)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='sigmoid')(inputs)

y = MaxPooling2D()(y)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='sigmoid')(y)

y = MaxPooling2D()(y)
# y = Conv2D(filters=filters,
#            kernel_size=kernel_size,
#            activation='relu')(y)
# image to vector before connecting to dense layer
y = Flatten()(y)
# dropout regularization
#y = Dropout(dropout)(y)
outputs = Dense(num_labels, activation='softmax')(y)



# build the model by supplying inputs/outputs
model = Model(inputs=inputs, outputs=outputs)
# network model in text
model.summary()
# Retrieve the config
import tensorflow
from tensorflow.keras.optimizers import Adam
# classifier loss, Adam optimizer, classifier accuracy
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.0001),
              metrics=['accuracy'])

import time

start_time = time.time()


# train the model with input images and labels
model.fit(x_train,
          y_train,
          validation_data=(x_test, y_test),
          epochs=50,
          batch_size=batch_size)

end_time = time.time()
execution_time = end_time - start_time

# model accuracy on test dataset
score = model.evaluate(x_test,
                       y_test,
                       batch_size=batch_size,
                       verbose=0)
print("\nTest accuracy: %.1f%%" % (100.0 * score[1]))
print("Execution time: {:.2f} seconds".format(execution_time))
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_6 (Conv2D)           (None, 26, 26, 64)        640
#
#  max_pooling2d_6 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_7 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten_2 (Flatten)         (None, 1600)              0
#
#  dense_2 (Dense)             (None, 10)                16010
#
# =================================================================
# Total params: 53,578
# Trainable params: 53,578
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 3s 5ms/step - loss: 2.2957 - accuracy: 0.1279 - val_loss: 2.2678 - val_accuracy: 0.2110
# Epoch 2/50
# 469/469 [==============================] - 2s 4ms/step - loss: 2.1409 - accuracy: 0.3695 - val_loss: 1.8194 - val_accuracy: 0.5834
# Epoch 3/50
# 469/469 [==============================] - 2s 4ms/step - loss: 1.2385 - accuracy: 0.7507 - val_loss: 0.7862 - val_accuracy: 0.8244
# Epoch 4/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.6539 - accuracy: 0.8367 - val_loss: 0.5320 - val_accuracy: 0.8606
# Epoch 5/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.4921 - accuracy: 0.8682 - val_loss: 0.4254 - val_accuracy: 0.8848
# Epoch 6/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.4130 - accuracy: 0.8852 - val_loss: 0.3661 - val_accuracy: 0.8968
# Epoch 7/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3607 - accuracy: 0.8990 - val_loss: 0.3227 - val_accuracy: 0.9104
# Epoch 8/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.3203 - accuracy: 0.9097 - val_loss: 0.2892 - val_accuracy: 0.9171
# Epoch 9/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2872 - accuracy: 0.9192 - val_loss: 0.2565 - val_accuracy: 0.9263
# Epoch 10/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2588 - accuracy: 0.9274 - val_loss: 0.2338 - val_accuracy: 0.9345
# Epoch 11/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2349 - accuracy: 0.9344 - val_loss: 0.2123 - val_accuracy: 0.9401
# Epoch 12/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.2138 - accuracy: 0.9401 - val_loss: 0.1946 - val_accuracy: 0.9447
# Epoch 13/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1958 - accuracy: 0.9454 - val_loss: 0.1754 - val_accuracy: 0.9515
# Epoch 14/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1804 - accuracy: 0.9496 - val_loss: 0.1615 - val_accuracy: 0.9559
# Epoch 15/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1669 - accuracy: 0.9532 - val_loss: 0.1519 - val_accuracy: 0.9584
# Epoch 16/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1556 - accuracy: 0.9569 - val_loss: 0.1407 - val_accuracy: 0.9610
# Epoch 17/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1455 - accuracy: 0.9599 - val_loss: 0.1329 - val_accuracy: 0.9638
# Epoch 18/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1368 - accuracy: 0.9622 - val_loss: 0.1245 - val_accuracy: 0.9662
# Epoch 19/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1295 - accuracy: 0.9644 - val_loss: 0.1183 - val_accuracy: 0.9678
# Epoch 20/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1227 - accuracy: 0.9660 - val_loss: 0.1119 - val_accuracy: 0.9695
# Epoch 21/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1169 - accuracy: 0.9673 - val_loss: 0.1078 - val_accuracy: 0.9705
# Epoch 22/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1115 - accuracy: 0.9688 - val_loss: 0.1032 - val_accuracy: 0.9715
# Epoch 23/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1067 - accuracy: 0.9698 - val_loss: 0.0991 - val_accuracy: 0.9721
# Epoch 24/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.1027 - accuracy: 0.9709 - val_loss: 0.0963 - val_accuracy: 0.9723
# Epoch 25/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0990 - accuracy: 0.9717 - val_loss: 0.0920 - val_accuracy: 0.9742
# Epoch 26/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0954 - accuracy: 0.9729 - val_loss: 0.0885 - val_accuracy: 0.9753
# Epoch 27/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0921 - accuracy: 0.9736 - val_loss: 0.0864 - val_accuracy: 0.9752
# Epoch 28/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0893 - accuracy: 0.9743 - val_loss: 0.0836 - val_accuracy: 0.9757
# Epoch 29/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0867 - accuracy: 0.9747 - val_loss: 0.0813 - val_accuracy: 0.9767
# Epoch 30/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0843 - accuracy: 0.9755 - val_loss: 0.0785 - val_accuracy: 0.9772
# Epoch 31/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0821 - accuracy: 0.9766 - val_loss: 0.0763 - val_accuracy: 0.9774
# Epoch 32/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0798 - accuracy: 0.9770 - val_loss: 0.0752 - val_accuracy: 0.9762
# Epoch 33/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0778 - accuracy: 0.9775 - val_loss: 0.0730 - val_accuracy: 0.9788
# Epoch 34/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0759 - accuracy: 0.9781 - val_loss: 0.0718 - val_accuracy: 0.9783
# Epoch 35/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0744 - accuracy: 0.9787 - val_loss: 0.0699 - val_accuracy: 0.9791
# Epoch 36/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0724 - accuracy: 0.9791 - val_loss: 0.0709 - val_accuracy: 0.9786
# Epoch 37/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0711 - accuracy: 0.9796 - val_loss: 0.0677 - val_accuracy: 0.9789
# Epoch 38/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0696 - accuracy: 0.9799 - val_loss: 0.0668 - val_accuracy: 0.9800
# Epoch 39/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0681 - accuracy: 0.9805 - val_loss: 0.0656 - val_accuracy: 0.9801
# Epoch 40/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0669 - accuracy: 0.9805 - val_loss: 0.0647 - val_accuracy: 0.9811
# Epoch 41/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0655 - accuracy: 0.9810 - val_loss: 0.0632 - val_accuracy: 0.9807
# Epoch 42/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0641 - accuracy: 0.9818 - val_loss: 0.0619 - val_accuracy: 0.9817
# Epoch 43/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0631 - accuracy: 0.9819 - val_loss: 0.0626 - val_accuracy: 0.9816
# Epoch 44/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0621 - accuracy: 0.9820 - val_loss: 0.0601 - val_accuracy: 0.9815
# Epoch 45/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0610 - accuracy: 0.9826 - val_loss: 0.0595 - val_accuracy: 0.9822
# Epoch 46/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0600 - accuracy: 0.9826 - val_loss: 0.0581 - val_accuracy: 0.9822
# Epoch 47/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0591 - accuracy: 0.9832 - val_loss: 0.0576 - val_accuracy: 0.9825
# Epoch 48/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0579 - accuracy: 0.9834 - val_loss: 0.0571 - val_accuracy: 0.9821
# Epoch 49/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0572 - accuracy: 0.9839 - val_loss: 0.0557 - val_accuracy: 0.9832
# Epoch 50/50
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0562 - accuracy: 0.9839 - val_loss: 0.0554 - val_accuracy: 0.9834
#
# Test accuracy: 98.3%
# Execution time: 87.91 seconds
