# %%
# Imnporting Libraries
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf

# Custom activation function
from keras.layers import Activation
from keras import backend as k
import tensorflow as tf
from tensorflow import keras
import keras.utils as generic_utils
import tensorflow.python.keras.utils as generic_utils
from tensorflow.keras.utils import get_custom_objects


@tf.function
def custom_activation(x):
  #def f1(): return k.tf.add(0.001,k.tf.add(x,7.5))
  def f3(): return k.tf.add(0.3435,k.tf.multiply(tf.cast(x, tf.float32),0.107))
  def f5(): return k.tf.add(0.5,k.tf.multiply(tf.cast(x, tf.float32),0.231))
  def f7(): return k.tf.add(0.8075,k.tf.multiply(tf.cast(x, tf.float32),0.047))
  def f9(): return k.tf.ones([1,1],tf.float32)


  def f6(): return k.tf.where(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), 1), tf.less(tf.cast(x, tf.float32), 5)),x=f7(),y=f9())
  def f4(): return k.tf.where(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), -1), tf.less(tf.cast(x, tf.float32), 1)),x=f5(),y=f6())
  def f2(): return k.tf.where(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), -5), tf.less(tf.cast(x, tf.float32), -1)),x=f3(),y=f4())


  r = tf.where(
         condition=(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), -10), tf.less(tf.cast(x, tf.float32), -5))),
         x=k.tf.add(0.0085,k.tf.multiply(tf.cast(x, tf.float32),0.001)),
         y=f2()
     )

  return r

# 0
# 0.002 + 0.001(x+6.25) -> 0.00825+0.001x
# 0.023 + 0.007(x+3.75) -> 0.4925+0.007x
# 0.245 + 0.076(x+1.125) -> 0.3305+0.076x
# 0.755 + 0.207(x-1.125) -> 0.5222-0.207x
# 0.977 + 0.099(x-3.75) -> 0.6058-0.099x
# 0.998 + 0.012(x-6.25) -> 0.923-0.012x
# 1.0 + 0.001(x-8.75) -> 0.99125-0.001x

# k.tf.zeros([1,1], tf.float32)
"""
  r = K.tf.where(
         condition=(K.tf.logical_and(K.tf.greater(x, -10), K.tf.less(x, -5))),
         x=K.tf.add(0.001,K.tf.add(x,7.5)),
         y=f2()
     )
"""
#tf.logical_or((tf.logical_and(tf.greater(x, -10), tf.less(x, -5))), (tf.logical_and(tf.greater(x, -5), tf.less(x, 5)) )


    #def f1(): return tf.add(0.5,tf.multi(0.099,x))

    # return tf.where(
    #     condition=tf.logical_or((tf.logical_and(tf.greater(x, -10), tf.less(x, -5))), (tf.logical_and(tf.greater(x, -5), tf.less(x, 5)) )),
    #     x=tf.add(0.001,tf.add(x,7.5)),
    #     y=tf.add(0.5,tf.multiply(0.099,x))
    # )

"""
  x =tf.dtypes.cast(x, tf.int32)
  if (x > -10 & x < -5):
    y = 0.001 + 0.015*(x+7.5);
  if (x > -5 & x < 5):
    y = 0.5 + 0.099*x;
  if x > 5:
    y = 0.999;
  return y
"""
"""
loss = tf.where(
        condition=tf.logical_or((tf.logical_and(tf.greater(y_true, 0.0), tf.greater(y_pred, y_true))), (tf.logical_and(tf.less(y_true, 0.0), tf.less(y_pred, y_true)))),
        x=loss * penalty / 5,
        y=loss * penalty / 10
    )
"""
"""
# working
# tf.where(tf.less(x, 0), tf.add(0.5,tf.multiply(0.099,x)) ,tf.add(0.5,tf.multiply(0.099,x)))
"""
# tf.where(tf.less(x, 0), true_fn=lambda: tf.add(0.5,tf.multiply(0.099,x)), false_fn=lambda: tf.add(0.5,tf.multiply(0.099,x)))
# tf.cond(tf.logical_and(tf.less(x,-10),tf.greater(x,-5))):
"""
    if x > -5 and x < 5:
        return tf.add(0.5,tf.multi(0.099,x))
    if x > 5:
        return 0.999
"""
get_custom_objects().update({'custom_activation': Activation(custom_activation)})
"""
# Usage
model = Sequential()
model.add(Dense(32, input_dim=784))
model.add(Activation(custom_activation, name='SpecialActivation'))
print(model.summary())
"""
# Out:
# "\n# Usage\nmodel = Sequential()\nmodel.add(Dense(32, input_dim=784))\nmodel.add(Activation(custom_activation, name='SpecialActivation'))\nprint(model.summary())\n"

# %%
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

import tensorflow
tensorflow.random.set_seed(22)

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# from sparse label to categorical
num_labels = len(np.unique(y_train))
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# reshape and normalize input images
image_size = x_train.shape[1]
x_train = np.reshape(x_train,[-1, image_size, image_size, 1])
x_test = np.reshape(x_test,[-1, image_size, image_size, 1])
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# network parameters
input_shape = (image_size, image_size, 1)
batch_size = 128
kernel_size = 3
filters = 64
dropout = 0.3

# use functional API to build cnn layers
inputs = Input(shape=input_shape)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(inputs)

y = MaxPooling2D()(y)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(y)

y = MaxPooling2D()(y)
# y = Conv2D(filters=filters,
#            kernel_size=kernel_size,
#            activation='relu')(y)
# image to vector before connecting to dense layer
y = Flatten()(y)
# dropout regularization
#y = Dropout(dropout)(y)
outputs = Dense(num_labels, activation='softmax')(y)



# build the model by supplying inputs/outputs
model = Model(inputs=inputs, outputs=outputs)
# network model in text
model.summary()
# Retrieve the config
import tensorflow
from tensorflow.keras.optimizers import Adam
# classifier loss, Adam optimizer, classifier accuracy
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.0001),
              metrics=['accuracy'])

# train the model with input images and labels
model.fit(x_train,
          y_train,
          validation_data=(x_test, y_test),
          epochs=50,
          batch_size=batch_size)

# model accuracy on test dataset
score = model.evaluate(x_test,
                       y_test,
                       batch_size=batch_size,
                       verbose=0)
print("\nTest accuracy: %.1f%%" % (100.0 * score[1]))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 1600)              0
#
#  dense (Dense)               (None, 10)                16010
#
# =================================================================
# Total params: 53,578
# Trainable params: 53,578
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 18s 16ms/step - loss: 2.3046 - accuracy: 0.1111 - val_loss: 2.2900 - val_accuracy: 0.1067
# Epoch 2/50
# 469/469 [==============================] - 7s 15ms/step - loss: 2.2465 - accuracy: 0.2204 - val_loss: 2.1171 - val_accuracy: 0.3325
# Epoch 3/50
# 469/469 [==============================] - 7s 15ms/step - loss: 1.5703 - accuracy: 0.6579 - val_loss: 0.9674 - val_accuracy: 0.8092
# Epoch 4/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.7309 - accuracy: 0.8268 - val_loss: 0.5625 - val_accuracy: 0.8566
# Epoch 5/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.5082 - accuracy: 0.8672 - val_loss: 0.4310 - val_accuracy: 0.8856
# Epoch 6/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.4152 - accuracy: 0.8870 - val_loss: 0.3645 - val_accuracy: 0.9002
# Epoch 7/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.3594 - accuracy: 0.9010 - val_loss: 0.3200 - val_accuracy: 0.9128
# Epoch 8/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.3184 - accuracy: 0.9115 - val_loss: 0.2870 - val_accuracy: 0.9197
# Epoch 9/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2851 - accuracy: 0.9208 - val_loss: 0.2528 - val_accuracy: 0.9283
# Epoch 10/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2561 - accuracy: 0.9294 - val_loss: 0.2292 - val_accuracy: 0.9377
# Epoch 11/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2303 - accuracy: 0.9364 - val_loss: 0.2042 - val_accuracy: 0.9423
# Epoch 12/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2055 - accuracy: 0.9431 - val_loss: 0.1803 - val_accuracy: 0.9496
# Epoch 13/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1835 - accuracy: 0.9496 - val_loss: 0.1600 - val_accuracy: 0.9554
# Epoch 14/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1656 - accuracy: 0.9542 - val_loss: 0.1434 - val_accuracy: 0.9602
# Epoch 15/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1502 - accuracy: 0.9579 - val_loss: 0.1333 - val_accuracy: 0.9623
# Epoch 16/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1378 - accuracy: 0.9611 - val_loss: 0.1217 - val_accuracy: 0.9637
# Epoch 17/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1265 - accuracy: 0.9645 - val_loss: 0.1131 - val_accuracy: 0.9671
# Epoch 18/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1172 - accuracy: 0.9668 - val_loss: 0.1052 - val_accuracy: 0.9700
# Epoch 19/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1100 - accuracy: 0.9688 - val_loss: 0.0981 - val_accuracy: 0.9722
# Epoch 20/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1043 - accuracy: 0.9703 - val_loss: 0.0930 - val_accuracy: 0.9737
# Epoch 21/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0998 - accuracy: 0.9717 - val_loss: 0.0898 - val_accuracy: 0.9737
# Epoch 22/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0957 - accuracy: 0.9725 - val_loss: 0.0867 - val_accuracy: 0.9727
# Epoch 23/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0921 - accuracy: 0.9730 - val_loss: 0.0845 - val_accuracy: 0.9742
# Epoch 24/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0894 - accuracy: 0.9738 - val_loss: 0.0811 - val_accuracy: 0.9752
# Epoch 25/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0865 - accuracy: 0.9746 - val_loss: 0.0784 - val_accuracy: 0.9760
# Epoch 26/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0837 - accuracy: 0.9753 - val_loss: 0.0758 - val_accuracy: 0.9768
# Epoch 27/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0811 - accuracy: 0.9763 - val_loss: 0.0743 - val_accuracy: 0.9768
# Epoch 28/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0783 - accuracy: 0.9771 - val_loss: 0.0714 - val_accuracy: 0.9779
# Epoch 29/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0759 - accuracy: 0.9776 - val_loss: 0.0701 - val_accuracy: 0.9790
# Epoch 30/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0739 - accuracy: 0.9781 - val_loss: 0.0676 - val_accuracy: 0.9792
# Epoch 31/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0725 - accuracy: 0.9781 - val_loss: 0.0661 - val_accuracy: 0.9794
# Epoch 32/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0707 - accuracy: 0.9790 - val_loss: 0.0657 - val_accuracy: 0.9793
# Epoch 33/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0691 - accuracy: 0.9794 - val_loss: 0.0636 - val_accuracy: 0.9794
# Epoch 34/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0677 - accuracy: 0.9800 - val_loss: 0.0642 - val_accuracy: 0.9794
# Epoch 35/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0663 - accuracy: 0.9802 - val_loss: 0.0622 - val_accuracy: 0.9806
# Epoch 36/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0649 - accuracy: 0.9808 - val_loss: 0.0627 - val_accuracy: 0.9805
# Epoch 37/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0641 - accuracy: 0.9810 - val_loss: 0.0610 - val_accuracy: 0.9801
# Epoch 38/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0630 - accuracy: 0.9815 - val_loss: 0.0603 - val_accuracy: 0.9810
# Epoch 39/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0620 - accuracy: 0.9819 - val_loss: 0.0606 - val_accuracy: 0.9815
# Epoch 40/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0609 - accuracy: 0.9819 - val_loss: 0.0596 - val_accuracy: 0.9818
# Epoch 41/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0599 - accuracy: 0.9824 - val_loss: 0.0592 - val_accuracy: 0.9825
# Epoch 42/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0592 - accuracy: 0.9821 - val_loss: 0.0573 - val_accuracy: 0.9821
# Epoch 43/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0583 - accuracy: 0.9826 - val_loss: 0.0588 - val_accuracy: 0.9813
# Epoch 44/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0577 - accuracy: 0.9828 - val_loss: 0.0575 - val_accuracy: 0.9815
# Epoch 45/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0570 - accuracy: 0.9829 - val_loss: 0.0576 - val_accuracy: 0.9813
# Epoch 46/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0563 - accuracy: 0.9832 - val_loss: 0.0559 - val_accuracy: 0.9819
# Epoch 47/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0557 - accuracy: 0.9832 - val_loss: 0.0570 - val_accuracy: 0.9815
# Epoch 48/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0549 - accuracy: 0.9835 - val_loss: 0.0562 - val_accuracy: 0.9819
# Epoch 49/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0544 - accuracy: 0.9838 - val_loss: 0.0561 - val_accuracy: 0.9828
# Epoch 50/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0535 - accuracy: 0.9843 - val_loss: 0.0544 - val_accuracy: 0.9833
#
# Test accuracy: 98.3%

# %%
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

import tensorflow
tensorflow.random.set_seed(22)

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# from sparse label to categorical
num_labels = len(np.unique(y_train))
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# reshape and normalize input images
image_size = x_train.shape[1]
x_train = np.reshape(x_train,[-1, image_size, image_size, 1])
x_test = np.reshape(x_test,[-1, image_size, image_size, 1])
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# network parameters
input_shape = (image_size, image_size, 1)
batch_size = 128
kernel_size = 3
filters = 64
dropout = 0.3

# use functional API to build cnn layers
inputs = Input(shape=input_shape)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='sigmoid')(inputs)

y = MaxPooling2D()(y)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='sigmoid')(y)

y = MaxPooling2D()(y)
# y = Conv2D(filters=filters,
#            kernel_size=kernel_size,
#            activation='relu')(y)
# image to vector before connecting to dense layer
y = Flatten()(y)
# dropout regularization
#y = Dropout(dropout)(y)
outputs = Dense(num_labels, activation='softmax')(y)



# build the model by supplying inputs/outputs
model = Model(inputs=inputs, outputs=outputs)
# network model in text
model.summary()
# Retrieve the config
import tensorflow
from tensorflow.keras.optimizers import Adam
# classifier loss, Adam optimizer, classifier accuracy
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.0001),
              metrics=['accuracy'])

# train the model with input images and labels
model.fit(x_train,
          y_train,
          validation_data=(x_test, y_test),
          epochs=50,
          batch_size=batch_size)

# model accuracy on test dataset
score = model.evaluate(x_test,
                       y_test,
                       batch_size=batch_size,
                       verbose=0)
print("\nTest accuracy: %.1f%%" % (100.0 * score[1]))
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 26, 26, 64)        640
#
#  max_pooling2d_2 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 1600)              0
#
#  dense_1 (Dense)             (None, 10)                16010
#
# =================================================================
# Total params: 53,578
# Trainable params: 53,578
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 4s 6ms/step - loss: 2.3005 - accuracy: 0.1248 - val_loss: 2.2780 - val_accuracy: 0.1625
# Epoch 2/50
# 469/469 [==============================] - 3s 6ms/step - loss: 2.1913 - accuracy: 0.3029 - val_loss: 1.9638 - val_accuracy: 0.4685
# Epoch 3/50
# 469/469 [==============================] - 3s 6ms/step - loss: 1.4077 - accuracy: 0.7111 - val_loss: 0.8914 - val_accuracy: 0.8150
# Epoch 4/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.7110 - accuracy: 0.8291 - val_loss: 0.5616 - val_accuracy: 0.8573
# Epoch 5/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.5092 - accuracy: 0.8657 - val_loss: 0.4328 - val_accuracy: 0.8855
# Epoch 6/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4161 - accuracy: 0.8854 - val_loss: 0.3644 - val_accuracy: 0.9008
# Epoch 7/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3573 - accuracy: 0.9009 - val_loss: 0.3155 - val_accuracy: 0.9125
# Epoch 8/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3140 - accuracy: 0.9124 - val_loss: 0.2811 - val_accuracy: 0.9216
# Epoch 9/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2800 - accuracy: 0.9221 - val_loss: 0.2477 - val_accuracy: 0.9298
# Epoch 10/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2519 - accuracy: 0.9291 - val_loss: 0.2252 - val_accuracy: 0.9380
# Epoch 11/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2289 - accuracy: 0.9362 - val_loss: 0.2045 - val_accuracy: 0.9416
# Epoch 12/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2088 - accuracy: 0.9414 - val_loss: 0.1878 - val_accuracy: 0.9467
# Epoch 13/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1920 - accuracy: 0.9464 - val_loss: 0.1702 - val_accuracy: 0.9526
# Epoch 14/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1775 - accuracy: 0.9500 - val_loss: 0.1571 - val_accuracy: 0.9549
# Epoch 15/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1650 - accuracy: 0.9540 - val_loss: 0.1486 - val_accuracy: 0.9591
# Epoch 16/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1543 - accuracy: 0.9564 - val_loss: 0.1374 - val_accuracy: 0.9606
# Epoch 17/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1448 - accuracy: 0.9594 - val_loss: 0.1305 - val_accuracy: 0.9633
# Epoch 18/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1364 - accuracy: 0.9617 - val_loss: 0.1224 - val_accuracy: 0.9659
# Epoch 19/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1295 - accuracy: 0.9636 - val_loss: 0.1162 - val_accuracy: 0.9672
# Epoch 20/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1228 - accuracy: 0.9661 - val_loss: 0.1101 - val_accuracy: 0.9686
# Epoch 21/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1171 - accuracy: 0.9667 - val_loss: 0.1058 - val_accuracy: 0.9707
# Epoch 22/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1119 - accuracy: 0.9684 - val_loss: 0.1019 - val_accuracy: 0.9720
# Epoch 23/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1071 - accuracy: 0.9695 - val_loss: 0.0977 - val_accuracy: 0.9717
# Epoch 24/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1031 - accuracy: 0.9707 - val_loss: 0.0948 - val_accuracy: 0.9727
# Epoch 25/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0994 - accuracy: 0.9717 - val_loss: 0.0906 - val_accuracy: 0.9733
# Epoch 26/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0957 - accuracy: 0.9727 - val_loss: 0.0872 - val_accuracy: 0.9746
# Epoch 27/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0924 - accuracy: 0.9738 - val_loss: 0.0853 - val_accuracy: 0.9738
# Epoch 28/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0895 - accuracy: 0.9744 - val_loss: 0.0823 - val_accuracy: 0.9757
# Epoch 29/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0868 - accuracy: 0.9756 - val_loss: 0.0799 - val_accuracy: 0.9764
# Epoch 30/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0843 - accuracy: 0.9757 - val_loss: 0.0768 - val_accuracy: 0.9784
# Epoch 31/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0820 - accuracy: 0.9766 - val_loss: 0.0752 - val_accuracy: 0.9777
# Epoch 32/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0797 - accuracy: 0.9768 - val_loss: 0.0736 - val_accuracy: 0.9778
# Epoch 33/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0775 - accuracy: 0.9776 - val_loss: 0.0718 - val_accuracy: 0.9788
# Epoch 34/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0757 - accuracy: 0.9784 - val_loss: 0.0702 - val_accuracy: 0.9787
# Epoch 35/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0740 - accuracy: 0.9786 - val_loss: 0.0685 - val_accuracy: 0.9787
# Epoch 36/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0720 - accuracy: 0.9791 - val_loss: 0.0693 - val_accuracy: 0.9790
# Epoch 37/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0706 - accuracy: 0.9795 - val_loss: 0.0661 - val_accuracy: 0.9804
# Epoch 38/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0690 - accuracy: 0.9805 - val_loss: 0.0654 - val_accuracy: 0.9805
# Epoch 39/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0675 - accuracy: 0.9807 - val_loss: 0.0635 - val_accuracy: 0.9800
# Epoch 40/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0662 - accuracy: 0.9810 - val_loss: 0.0633 - val_accuracy: 0.9806
# Epoch 41/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0648 - accuracy: 0.9814 - val_loss: 0.0617 - val_accuracy: 0.9817
# Epoch 42/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0634 - accuracy: 0.9818 - val_loss: 0.0605 - val_accuracy: 0.9813
# Epoch 43/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0622 - accuracy: 0.9824 - val_loss: 0.0608 - val_accuracy: 0.9821
# Epoch 44/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0612 - accuracy: 0.9824 - val_loss: 0.0584 - val_accuracy: 0.9823
# Epoch 45/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0599 - accuracy: 0.9830 - val_loss: 0.0581 - val_accuracy: 0.9832
# Epoch 46/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0590 - accuracy: 0.9833 - val_loss: 0.0565 - val_accuracy: 0.9831
# Epoch 47/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0580 - accuracy: 0.9835 - val_loss: 0.0559 - val_accuracy: 0.9835
# Epoch 48/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0568 - accuracy: 0.9839 - val_loss: 0.0551 - val_accuracy: 0.9837
# Epoch 49/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0560 - accuracy: 0.9840 - val_loss: 0.0542 - val_accuracy: 0.9837
# Epoch 50/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0549 - accuracy: 0.9848 - val_loss: 0.0541 - val_accuracy: 0.9840
#
# Test accuracy: 98.4%
