# %%
# Imnporting Libraries
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf

# Custom activation function
from keras.layers import Activation
from keras import backend as k
import tensorflow as tf
from tensorflow import keras
import keras.utils as generic_utils
import tensorflow.python.keras.utils as generic_utils
from tensorflow.keras.utils import get_custom_objects


@tf.function
def custom_activation(x):
  #def f1(): return k.tf.add(0.001,k.tf.add(x,7.5))
  def f3(): return k.tf.add(0.3435,k.tf.multiply(tf.cast(x, tf.float32),0.107))
  def f5(): return k.tf.add(0.5,k.tf.multiply(tf.cast(x, tf.float32),0.231))
  def f7(): return k.tf.add(0.8075,k.tf.multiply(tf.cast(x, tf.float32),0.047))
  def f9(): return k.tf.ones([1,1],tf.float32)


  def f6(): return k.tf.where(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), 1), tf.less(tf.cast(x, tf.float32), 5)),x=f7(),y=f9())
  def f4(): return k.tf.where(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), -1), tf.less(tf.cast(x, tf.float32), 1)),x=f5(),y=f6())
  def f2(): return k.tf.where(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), -5), tf.less(tf.cast(x, tf.float32), -1)),x=f3(),y=f4())


  r = tf.where(
         condition=(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), -10), tf.less(tf.cast(x, tf.float32), -5))),
         x=k.tf.add(0.0085,k.tf.multiply(tf.cast(x, tf.float32),0.001)),
         y=f2()
     )

  return r

# 0
# 0.002 + 0.001(x+6.25) -> 0.00825+0.001x
# 0.023 + 0.007(x+3.75) -> 0.4925+0.007x
# 0.245 + 0.076(x+1.125) -> 0.3305+0.076x
# 0.755 + 0.207(x-1.125) -> 0.5222-0.207x
# 0.977 + 0.099(x-3.75) -> 0.6058-0.099x
# 0.998 + 0.012(x-6.25) -> 0.923-0.012x
# 1.0 + 0.001(x-8.75) -> 0.99125-0.001x

# k.tf.zeros([1,1], tf.float32)
"""
  r = K.tf.where(
         condition=(K.tf.logical_and(K.tf.greater(x, -10), K.tf.less(x, -5))),
         x=K.tf.add(0.001,K.tf.add(x,7.5)),
         y=f2()
     )
"""
#tf.logical_or((tf.logical_and(tf.greater(x, -10), tf.less(x, -5))), (tf.logical_and(tf.greater(x, -5), tf.less(x, 5)) )


    #def f1(): return tf.add(0.5,tf.multi(0.099,x))

    # return tf.where(
    #     condition=tf.logical_or((tf.logical_and(tf.greater(x, -10), tf.less(x, -5))), (tf.logical_and(tf.greater(x, -5), tf.less(x, 5)) )),
    #     x=tf.add(0.001,tf.add(x,7.5)),
    #     y=tf.add(0.5,tf.multiply(0.099,x))
    # )

"""
  x =tf.dtypes.cast(x, tf.int32)
  if (x > -10 & x < -5):
    y = 0.001 + 0.015*(x+7.5);
  if (x > -5 & x < 5):
    y = 0.5 + 0.099*x;
  if x > 5:
    y = 0.999;
  return y
"""
"""
loss = tf.where(
        condition=tf.logical_or((tf.logical_and(tf.greater(y_true, 0.0), tf.greater(y_pred, y_true))), (tf.logical_and(tf.less(y_true, 0.0), tf.less(y_pred, y_true)))),
        x=loss * penalty / 5,
        y=loss * penalty / 10
    )
"""
"""
# working
# tf.where(tf.less(x, 0), tf.add(0.5,tf.multiply(0.099,x)) ,tf.add(0.5,tf.multiply(0.099,x)))
"""
# tf.where(tf.less(x, 0), true_fn=lambda: tf.add(0.5,tf.multiply(0.099,x)), false_fn=lambda: tf.add(0.5,tf.multiply(0.099,x)))
# tf.cond(tf.logical_and(tf.less(x,-10),tf.greater(x,-5))):
"""
    if x > -5 and x < 5:
        return tf.add(0.5,tf.multi(0.099,x))
    if x > 5:
        return 0.999
"""
get_custom_objects().update({'custom_activation': Activation(custom_activation)})
"""
# Usage
model = Sequential()
model.add(Dense(32, input_dim=784))
model.add(Activation(custom_activation, name='SpecialActivation'))
print(model.summary())
"""
# Out:
# "\n# Usage\nmodel = Sequential()\nmodel.add(Dense(32, input_dim=784))\nmodel.add(Activation(custom_activation, name='SpecialActivation'))\nprint(model.summary())\n"

# %%
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

import tensorflow
tensorflow.random.set_seed(22)

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# from sparse label to categorical
num_labels = len(np.unique(y_train))
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# reshape and normalize input images
image_size = x_train.shape[1]
x_train = np.reshape(x_train,[-1, image_size, image_size, 1])
x_test = np.reshape(x_test,[-1, image_size, image_size, 1])
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# network parameters
input_shape = (image_size, image_size, 1)
batch_size = 128
kernel_size = 3
filters = 64
dropout = 0.3

# use functional API to build cnn layers
inputs = Input(shape=input_shape)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(inputs)

y = MaxPooling2D()(y)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(y)

y = MaxPooling2D()(y)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(y)

y = MaxPooling2D()(y)
# y = Conv2D(filters=filters,
#            kernel_size=kernel_size,
#            activation='relu')(y)
# image to vector before connecting to dense layer
y = Flatten()(y)
# dropout regularization
#y = Dropout(dropout)(y)
outputs = Dense(num_labels, activation='softmax')(y)



# build the model by supplying inputs/outputs
model = Model(inputs=inputs, outputs=outputs)
# network model in text
model.summary()
# Retrieve the config
import tensorflow
from tensorflow.keras.optimizers import Adam
# classifier loss, Adam optimizer, classifier accuracy
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.0001),
              metrics=['accuracy'])

# train the model with input images and labels
model.fit(x_train,
          y_train,
          validation_data=(x_test, y_test),
          epochs=50,
          batch_size=batch_size)

# model accuracy on test dataset
score = model.evaluate(x_test,
                       y_test,
                       batch_size=batch_size,
                       verbose=0)
print("\nTest accuracy: %.1f%%" % (100.0 * score[1]))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 64)          36928
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 10)                650
#
# =================================================================
# Total params: 75,146
# Trainable params: 75,146
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 20s 16ms/step - loss: 2.3036 - accuracy: 0.1117 - val_loss: 2.2996 - val_accuracy: 0.1135
# Epoch 2/50
# 469/469 [==============================] - 7s 15ms/step - loss: 2.2894 - accuracy: 0.1517 - val_loss: 2.2502 - val_accuracy: 0.2374
# Epoch 3/50
# 469/469 [==============================] - 7s 15ms/step - loss: 1.9873 - accuracy: 0.4803 - val_loss: 1.6079 - val_accuracy: 0.6517
# Epoch 4/50
# 469/469 [==============================] - 7s 15ms/step - loss: 1.3450 - accuracy: 0.7283 - val_loss: 1.0876 - val_accuracy: 0.7932
# Epoch 5/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.9640 - accuracy: 0.8081 - val_loss: 0.8065 - val_accuracy: 0.8372
# Epoch 6/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.7449 - accuracy: 0.8463 - val_loss: 0.6329 - val_accuracy: 0.8669
# Epoch 7/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.6003 - accuracy: 0.8692 - val_loss: 0.5181 - val_accuracy: 0.8866
# Epoch 8/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.4993 - accuracy: 0.8879 - val_loss: 0.4352 - val_accuracy: 0.9031
# Epoch 9/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.4242 - accuracy: 0.9025 - val_loss: 0.3723 - val_accuracy: 0.9104
# Epoch 10/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.3695 - accuracy: 0.9126 - val_loss: 0.3287 - val_accuracy: 0.9221
# Epoch 11/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.3279 - accuracy: 0.9208 - val_loss: 0.2908 - val_accuracy: 0.9291
# Epoch 12/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2937 - accuracy: 0.9276 - val_loss: 0.2643 - val_accuracy: 0.9351
# Epoch 13/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2674 - accuracy: 0.9331 - val_loss: 0.2410 - val_accuracy: 0.9399
# Epoch 14/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2462 - accuracy: 0.9375 - val_loss: 0.2232 - val_accuracy: 0.9418
# Epoch 15/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2287 - accuracy: 0.9416 - val_loss: 0.2095 - val_accuracy: 0.9456
# Epoch 16/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2143 - accuracy: 0.9441 - val_loss: 0.1945 - val_accuracy: 0.9502
# Epoch 17/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.2020 - accuracy: 0.9463 - val_loss: 0.1851 - val_accuracy: 0.9523
# Epoch 18/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1917 - accuracy: 0.9488 - val_loss: 0.1753 - val_accuracy: 0.9546
# Epoch 19/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1828 - accuracy: 0.9503 - val_loss: 0.1690 - val_accuracy: 0.9550
# Epoch 20/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1755 - accuracy: 0.9519 - val_loss: 0.1634 - val_accuracy: 0.9560
# Epoch 21/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1691 - accuracy: 0.9538 - val_loss: 0.1587 - val_accuracy: 0.9574
# Epoch 22/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1634 - accuracy: 0.9548 - val_loss: 0.1530 - val_accuracy: 0.9570
# Epoch 23/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1587 - accuracy: 0.9559 - val_loss: 0.1501 - val_accuracy: 0.9580
# Epoch 24/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1546 - accuracy: 0.9573 - val_loss: 0.1451 - val_accuracy: 0.9582
# Epoch 25/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1498 - accuracy: 0.9587 - val_loss: 0.1398 - val_accuracy: 0.9617
# Epoch 26/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1460 - accuracy: 0.9594 - val_loss: 0.1377 - val_accuracy: 0.9605
# Epoch 27/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1418 - accuracy: 0.9603 - val_loss: 0.1335 - val_accuracy: 0.9603
# Epoch 28/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1385 - accuracy: 0.9612 - val_loss: 0.1319 - val_accuracy: 0.9612
# Epoch 29/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1352 - accuracy: 0.9620 - val_loss: 0.1288 - val_accuracy: 0.9625
# Epoch 30/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1322 - accuracy: 0.9629 - val_loss: 0.1265 - val_accuracy: 0.9638
# Epoch 31/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1296 - accuracy: 0.9639 - val_loss: 0.1234 - val_accuracy: 0.9637
# Epoch 32/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1269 - accuracy: 0.9651 - val_loss: 0.1248 - val_accuracy: 0.9629
# Epoch 33/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1241 - accuracy: 0.9653 - val_loss: 0.1203 - val_accuracy: 0.9649
# Epoch 34/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1229 - accuracy: 0.9656 - val_loss: 0.1185 - val_accuracy: 0.9641
# Epoch 35/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1211 - accuracy: 0.9662 - val_loss: 0.1172 - val_accuracy: 0.9643
# Epoch 36/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1188 - accuracy: 0.9666 - val_loss: 0.1161 - val_accuracy: 0.9657
# Epoch 37/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1167 - accuracy: 0.9668 - val_loss: 0.1158 - val_accuracy: 0.9659
# Epoch 38/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1158 - accuracy: 0.9675 - val_loss: 0.1140 - val_accuracy: 0.9660
# Epoch 39/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1135 - accuracy: 0.9677 - val_loss: 0.1141 - val_accuracy: 0.9667
# Epoch 40/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1116 - accuracy: 0.9685 - val_loss: 0.1120 - val_accuracy: 0.9673
# Epoch 41/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1099 - accuracy: 0.9695 - val_loss: 0.1100 - val_accuracy: 0.9664
# Epoch 42/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1079 - accuracy: 0.9696 - val_loss: 0.1096 - val_accuracy: 0.9684
# Epoch 43/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1069 - accuracy: 0.9701 - val_loss: 0.1082 - val_accuracy: 0.9680
# Epoch 44/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1052 - accuracy: 0.9707 - val_loss: 0.1051 - val_accuracy: 0.9699
# Epoch 45/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1035 - accuracy: 0.9713 - val_loss: 0.1063 - val_accuracy: 0.9689
# Epoch 46/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1027 - accuracy: 0.9715 - val_loss: 0.1070 - val_accuracy: 0.9680
# Epoch 47/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1016 - accuracy: 0.9713 - val_loss: 0.1030 - val_accuracy: 0.9695
# Epoch 48/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0998 - accuracy: 0.9722 - val_loss: 0.1049 - val_accuracy: 0.9695
# Epoch 49/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.1000 - accuracy: 0.9718 - val_loss: 0.1024 - val_accuracy: 0.9704
# Epoch 50/50
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0979 - accuracy: 0.9726 - val_loss: 0.1035 - val_accuracy: 0.9695
#
# Test accuracy: 97.0%

# %%
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

import tensorflow
tensorflow.random.set_seed(22)

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# from sparse label to categorical
num_labels = len(np.unique(y_train))
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# reshape and normalize input images
image_size = x_train.shape[1]
x_train = np.reshape(x_train,[-1, image_size, image_size, 1])
x_test = np.reshape(x_test,[-1, image_size, image_size, 1])
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# network parameters
input_shape = (image_size, image_size, 1)
batch_size = 128
kernel_size = 3
filters = 64
dropout = 0.3

# use functional API to build cnn layers
inputs = Input(shape=input_shape)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='sigmoid')(inputs)

y = MaxPooling2D()(y)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='sigmoid')(y)

y = MaxPooling2D()(y)
# y = Conv2D(filters=filters,
#            kernel_size=kernel_size,
#            activation='relu')(y)
# image to vector before connecting to dense layer

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='sigmoid')(y)

y = MaxPooling2D()(y)

y = Flatten()(y)
# dropout regularization
#y = Dropout(dropout)(y)
outputs = Dense(num_labels, activation='softmax')(y)



# build the model by supplying inputs/outputs
model = Model(inputs=inputs, outputs=outputs)
# network model in text
model.summary()
# Retrieve the config
import tensorflow
from tensorflow.keras.optimizers import Adam
# classifier loss, Adam optimizer, classifier accuracy
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.0001),
              metrics=['accuracy'])

# train the model with input images and labels
model.fit(x_train,
          y_train,
          validation_data=(x_test, y_test),
          epochs=50,
          batch_size=batch_size)

# model accuracy on test dataset
score = model.evaluate(x_test,
                       y_test,
                       batch_size=batch_size,
                       verbose=0)
print("\nTest accuracy: %.1f%%" % (100.0 * score[1]))
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_3 (Conv2D)           (None, 26, 26, 64)        640
#
#  max_pooling2d_3 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 64)          36928
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 75,146
# Trainable params: 75,146
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 5s 6ms/step - loss: 2.3054 - accuracy: 0.1106 - val_loss: 2.2989 - val_accuracy: 0.1135
# Epoch 2/50
# 469/469 [==============================] - 3s 6ms/step - loss: 2.2908 - accuracy: 0.1431 - val_loss: 2.2656 - val_accuracy: 0.2077
# Epoch 3/50
# 469/469 [==============================] - 3s 6ms/step - loss: 2.0843 - accuracy: 0.3923 - val_loss: 1.7380 - val_accuracy: 0.6020
# Epoch 4/50
# 469/469 [==============================] - 3s 6ms/step - loss: 1.4314 - accuracy: 0.6772 - val_loss: 1.1391 - val_accuracy: 0.7643
# Epoch 5/50
# 469/469 [==============================] - 3s 6ms/step - loss: 1.0055 - accuracy: 0.7806 - val_loss: 0.8392 - val_accuracy: 0.8241
# Epoch 6/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.7714 - accuracy: 0.8285 - val_loss: 0.6619 - val_accuracy: 0.8540
# Epoch 7/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.6244 - accuracy: 0.8581 - val_loss: 0.5458 - val_accuracy: 0.8746
# Epoch 8/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.5239 - accuracy: 0.8778 - val_loss: 0.4633 - val_accuracy: 0.8931
# Epoch 9/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4514 - accuracy: 0.8929 - val_loss: 0.4020 - val_accuracy: 0.9031
# Epoch 10/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3964 - accuracy: 0.9045 - val_loss: 0.3563 - val_accuracy: 0.9125
# Epoch 11/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3536 - accuracy: 0.9129 - val_loss: 0.3187 - val_accuracy: 0.9189
# Epoch 12/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3192 - accuracy: 0.9203 - val_loss: 0.2900 - val_accuracy: 0.9242
# Epoch 13/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2910 - accuracy: 0.9254 - val_loss: 0.2642 - val_accuracy: 0.9299
# Epoch 14/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2674 - accuracy: 0.9312 - val_loss: 0.2438 - val_accuracy: 0.9334
# Epoch 15/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2475 - accuracy: 0.9360 - val_loss: 0.2273 - val_accuracy: 0.9377
# Epoch 16/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2306 - accuracy: 0.9395 - val_loss: 0.2109 - val_accuracy: 0.9431
# Epoch 17/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2158 - accuracy: 0.9427 - val_loss: 0.1992 - val_accuracy: 0.9446
# Epoch 18/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2027 - accuracy: 0.9466 - val_loss: 0.1868 - val_accuracy: 0.9479
# Epoch 19/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1914 - accuracy: 0.9488 - val_loss: 0.1767 - val_accuracy: 0.9504
# Epoch 20/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1812 - accuracy: 0.9516 - val_loss: 0.1674 - val_accuracy: 0.9527
# Epoch 21/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1723 - accuracy: 0.9538 - val_loss: 0.1598 - val_accuracy: 0.9550
# Epoch 22/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1641 - accuracy: 0.9553 - val_loss: 0.1529 - val_accuracy: 0.9568
# Epoch 23/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1565 - accuracy: 0.9577 - val_loss: 0.1464 - val_accuracy: 0.9573
# Epoch 24/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1500 - accuracy: 0.9592 - val_loss: 0.1408 - val_accuracy: 0.9595
# Epoch 25/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1438 - accuracy: 0.9607 - val_loss: 0.1351 - val_accuracy: 0.9615
# Epoch 26/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1383 - accuracy: 0.9620 - val_loss: 0.1302 - val_accuracy: 0.9641
# Epoch 27/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1330 - accuracy: 0.9637 - val_loss: 0.1258 - val_accuracy: 0.9641
# Epoch 28/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1283 - accuracy: 0.9649 - val_loss: 0.1212 - val_accuracy: 0.9658
# Epoch 29/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1240 - accuracy: 0.9659 - val_loss: 0.1180 - val_accuracy: 0.9664
# Epoch 30/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1200 - accuracy: 0.9672 - val_loss: 0.1140 - val_accuracy: 0.9670
# Epoch 31/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1162 - accuracy: 0.9677 - val_loss: 0.1114 - val_accuracy: 0.9684
# Epoch 32/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1126 - accuracy: 0.9690 - val_loss: 0.1087 - val_accuracy: 0.9693
# Epoch 33/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1094 - accuracy: 0.9696 - val_loss: 0.1050 - val_accuracy: 0.9708
# Epoch 34/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1064 - accuracy: 0.9706 - val_loss: 0.1030 - val_accuracy: 0.9711
# Epoch 35/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1035 - accuracy: 0.9712 - val_loss: 0.1002 - val_accuracy: 0.9728
# Epoch 36/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1006 - accuracy: 0.9721 - val_loss: 0.0997 - val_accuracy: 0.9722
# Epoch 37/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0982 - accuracy: 0.9728 - val_loss: 0.0954 - val_accuracy: 0.9742
# Epoch 38/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0957 - accuracy: 0.9733 - val_loss: 0.0956 - val_accuracy: 0.9732
# Epoch 39/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0937 - accuracy: 0.9740 - val_loss: 0.0931 - val_accuracy: 0.9744
# Epoch 40/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0915 - accuracy: 0.9746 - val_loss: 0.0902 - val_accuracy: 0.9752
# Epoch 41/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0892 - accuracy: 0.9754 - val_loss: 0.0891 - val_accuracy: 0.9751
# Epoch 42/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0874 - accuracy: 0.9757 - val_loss: 0.0872 - val_accuracy: 0.9759
# Epoch 43/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0855 - accuracy: 0.9764 - val_loss: 0.0862 - val_accuracy: 0.9757
# Epoch 44/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0838 - accuracy: 0.9769 - val_loss: 0.0846 - val_accuracy: 0.9757
# Epoch 45/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0821 - accuracy: 0.9773 - val_loss: 0.0839 - val_accuracy: 0.9767
# Epoch 46/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0803 - accuracy: 0.9777 - val_loss: 0.0816 - val_accuracy: 0.9772
# Epoch 47/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0789 - accuracy: 0.9782 - val_loss: 0.0800 - val_accuracy: 0.9774
# Epoch 48/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0773 - accuracy: 0.9789 - val_loss: 0.0788 - val_accuracy: 0.9775
# Epoch 49/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0758 - accuracy: 0.9786 - val_loss: 0.0793 - val_accuracy: 0.9768
# Epoch 50/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0744 - accuracy: 0.9793 - val_loss: 0.0773 - val_accuracy: 0.9777
#
# Test accuracy: 97.8%
