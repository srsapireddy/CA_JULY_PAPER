# %% [markdown]
# **ORIGINAL TEST**

# %%
# Imnporting Libraries
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf
import numpy as np
# Custom activation function
from keras.layers import Activation
from keras import backend as K
import tensorflow as tf
from tensorflow import keras
import keras.utils as generic_utils
import tensorflow.python.keras.utils as generic_utils
from tensorflow.keras.utils import get_custom_objects


@tf.function
def custom_activation(x):

  #def f1(): return 0.001
  def f3(): return K.tf.add(0.5,K.tf.multiply(tf.cast(x, tf.float32),0.231))
  def f4(): return K.tf.add(0.986,K.tf.multiply(0.002,tf.cast(x, tf.float32)))
  def f2(): return K.tf.where(K.tf.logical_and(K.tf.greater(tf.cast(x, tf.float32), -2.5), K.tf.less(tf.cast(x, tf.float32), 2.5)),x=f3(),y=f4())



  r = K.tf.where(
         condition=(K.tf.logical_and(K.tf.greater(tf.cast(x, tf.float32), -10), K.tf.less(tf.cast(x, tf.float32), -2.5))),
         x=K.tf.add(0.026,K.tf.multiply(0.004,tf.cast(x, tf.float32))),
         y=f2())

  return r


get_custom_objects().update({'custom_activation': Activation(custom_activation)})

# %%
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

import tensorflow
tensorflow.random.set_seed(22)

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# from sparse label to categorical
num_labels = len(np.unique(y_train))
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# reshape and normalize input images
image_size = x_train.shape[1]
x_train = np.reshape(x_train,[-1, image_size, image_size, 1])
x_test = np.reshape(x_test,[-1, image_size, image_size, 1])
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# network parameters
input_shape = (image_size, image_size, 1)
batch_size = 128
kernel_size = 3
filters = 64
dropout = 0.3

# use functional API to build cnn layers
inputs = Input(shape=input_shape)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(inputs)

y = MaxPooling2D()(y)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(y)

y = MaxPooling2D()(y)
# y = Conv2D(filters=filters,
#            kernel_size=kernel_size,
#            activation='relu')(y)
# image to vector before connecting to dense layer
y = Flatten()(y)
# dropout regularization
#y = Dropout(dropout)(y)
outputs = Dense(num_labels, activation='softmax')(y)



# build the model by supplying inputs/outputs
model = Model(inputs=inputs, outputs=outputs)
# network model in text
model.summary()
# Retrieve the config
import tensorflow
from tensorflow.keras.optimizers import Adam
# classifier loss, Adam optimizer, classifier accuracy
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.0001),
              metrics=['accuracy'])
import time

start_time = time.time()
# train the model with input images and labels
model.fit(x_train,
          y_train,
          validation_data=(x_test, y_test),
          epochs=50,
          batch_size=batch_size)
end_time = time.time()
execution_time = end_time - start_time

print("Execution time: {:.2f} seconds".format(execution_time))
# model accuracy on test dataset
score = model.evaluate(x_test,
                       y_test,
                       batch_size=batch_size,
                       verbose=0)
print("\nTest accuracy: %.1f%%" % (100.0 * score[1]))
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_4 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_6 (Conv2D)           (None, 26, 26, 64)        640
#
#  max_pooling2d_6 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_7 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten_3 (Flatten)         (None, 1600)              0
#
#  dense_3 (Dense)             (None, 10)                16010
#
# ...
# Total params: 53,578
# Trainable params: 53,578
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 4s 5ms/step - loss: 2.2975 - accuracy: 0.1229 - val_loss: 2.2757 - val_accuracy: 0.1424
# Epoch 2/50
# ...

# %%
def count_flops(model):
    flops = 0
    for layer in model.layers:
        layer_flops = 0
        if isinstance(layer, keras.layers.Conv2D):
            # Count flops for Conv2D layer
            kernel_flops = layer.kernel_size[0] * layer.kernel_size[1] * layer.input_shape[-1]
            output_size = np.prod(layer.output_shape[1:])
            layer_flops = kernel_flops * output_size
        elif isinstance(layer, keras.layers.Dense):
            # Count flops for Dense layer
            layer_flops = layer.input_shape[-1] * layer.units
        flops += layer_flops
    return flops

total_flops = count_flops(model)
print("Number of FLOPs: {:.2f}".format(total_flops))
# Out:
# Number of FLOPs: 4865920.00

# %% [markdown]
# **TEST WITH SINGLE SLOPE AT 0**

# %%
# Imnporting Libraries
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf
import numpy as np
# Custom activation function
from keras.layers import Activation
from keras import backend as K
import tensorflow as tf
from tensorflow import keras
import keras.utils as generic_utils
import tensorflow.python.keras.utils as generic_utils
from tensorflow.keras.utils import get_custom_objects


@tf.function
def custom_activation(x):

  #def f1(): return 0.001
  def f3(): return K.tf.add(0.5,K.tf.multiply(tf.cast(x, tf.float32),0.231))
  def f4(): return K.tf.add(1.0,K.tf.multiply(0.0,tf.cast(x, tf.float32)))
  def f2(): return K.tf.where(K.tf.logical_and(K.tf.greater(tf.cast(x, tf.float32), -2.5), K.tf.less(tf.cast(x, tf.float32), 2.5)),x=f3(),y=f4())



  r = K.tf.where(
         condition=(K.tf.logical_and(K.tf.greater(tf.cast(x, tf.float32), -10), K.tf.less(tf.cast(x, tf.float32), -2.5))),
         x=K.tf.add(0.0,K.tf.multiply(0.0,tf.cast(x, tf.float32))),
         y=f2())

  return r


get_custom_objects().update({'custom_activation': Activation(custom_activation)})

# %%
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

import tensorflow
tensorflow.random.set_seed(22)

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# from sparse label to categorical
num_labels = len(np.unique(y_train))
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# reshape and normalize input images
image_size = x_train.shape[1]
x_train = np.reshape(x_train,[-1, image_size, image_size, 1])
x_test = np.reshape(x_test,[-1, image_size, image_size, 1])
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# network parameters
input_shape = (image_size, image_size, 1)
batch_size = 128
kernel_size = 3
filters = 64
dropout = 0.3

# use functional API to build cnn layers
inputs = Input(shape=input_shape)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(inputs)

y = MaxPooling2D()(y)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(y)

y = MaxPooling2D()(y)
# y = Conv2D(filters=filters,
#            kernel_size=kernel_size,
#            activation='relu')(y)
# image to vector before connecting to dense layer
y = Flatten()(y)
# dropout regularization
#y = Dropout(dropout)(y)
outputs = Dense(num_labels, activation='softmax')(y)



# build the model by supplying inputs/outputs
model_1 = Model(inputs=inputs, outputs=outputs)
# network model in text
model_1.summary()
# Retrieve the config
import tensorflow
from tensorflow.keras.optimizers import Adam
# classifier loss, Adam optimizer, classifier accuracy
model_1.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.0001),
              metrics=['accuracy'])

import time

start_time = time.time()
# train the model with input images and labels
model_1.fit(x_train,
          y_train,
          validation_data=(x_test, y_test),
          epochs=50,
          batch_size=batch_size)
end_time = time.time()
execution_time = end_time - start_time

print("Execution time: {:.2f} seconds".format(execution_time))

# model accuracy on test dataset
score = model_1.evaluate(x_test,
                       y_test,
                       batch_size=batch_size,
                       verbose=0)
print("\nTest accuracy: %.1f%%" % (100.0 * score[1]))
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_5 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_8 (Conv2D)           (None, 26, 26, 64)        640
#
#  max_pooling2d_8 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_9 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  flatten_4 (Flatten)         (None, 1600)              0
#
#  dense_4 (Dense)             (None, 10)                16010
#
# ...
# Total params: 53,578
# Trainable params: 53,578
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 4s 5ms/step - loss: 2.3018 - accuracy: 0.1169 - val_loss: 2.2827 - val_accuracy: 0.1414
# Epoch 2/50
# ...

# %%
def count_flops(model):
    flops = 0
    for layer in model.layers:
        layer_flops = 0
        if isinstance(layer, keras.layers.Conv2D):
            # Count flops for Conv2D layer
            kernel_flops = layer.kernel_size[0] * layer.kernel_size[1] * layer.input_shape[-1]
            output_size = np.prod(layer.output_shape[1:])
            layer_flops = kernel_flops * output_size
        elif isinstance(layer, keras.layers.Dense):
            # Count flops for Dense layer
            layer_flops = layer.input_shape[-1] * layer.units
        flops += layer_flops
    return flops

total_flops = count_flops(model_1)
print("Number of FLOPs: {:.2f}".format(total_flops))
# Out:
# Number of FLOPs: 4865920.00

# %%
def count_flops(model):
    flops_mul = 0
    flops_add = 0
    flops_div = 0
    flops_sub = 0

    for layer in model.layers:
        layer_flops_mul = 0
        layer_flops_add = 0
        layer_flops_div = 0
        layer_flops_sub = 0

        if isinstance(layer, keras.layers.Conv2D):
            # Count flops for Conv2D layer
            kernel_flops = layer.kernel_size[0] * layer.kernel_size[1] * layer.input_shape[-1]
            output_size = np.prod(layer.output_shape[1:])
            layer_flops_mul = kernel_flops * output_size
            layer_flops_add = (kernel_flops - 1) * output_size
        elif isinstance(layer, keras.layers.Dense):
            # Count flops for Dense layer
            layer_flops_mul = layer.input_shape[-1] * layer.units
            layer_flops_add = (layer.input_shape[-1] - 1) * layer.units

        flops_mul += layer_flops_mul
        flops_add += layer_flops_add
        flops_div += layer_flops_div
        flops_sub += layer_flops_sub

    return flops_mul, flops_add, flops_div, flops_sub

flops_mul, flops_add, flops_div, flops_sub = count_flops(model_1)
print("Number of FLOPs - Multiply: {:.2f}".format(flops_mul))
print("Number of FLOPs - Add: {:.2f}".format(flops_add))
print("Number of FLOPs - Divide: {:.2f}".format(flops_div))
print("Number of FLOPs - Subtract: {:.2f}".format(flops_sub))
# Out:
# Number of FLOPs - Multiply: 4865920.00
# Number of FLOPs - Add: 4814902.00
# Number of FLOPs - Divide: 0.00
# Number of FLOPs - Subtract: 0.00

# %%
def count_flops(model):
    flops_activation = 0

    for layer in model.layers:
        layer_flops_activation = 0

        if isinstance(layer, keras.layers.Conv2D):
            # Count flops for Conv2D layer
            kernel_flops = layer.kernel_size[0] * layer.kernel_size[1] * layer.input_shape[-1]
            output_size = np.prod(layer.output_shape[1:])
            layer_flops_activation = output_size
        elif isinstance(layer, keras.layers.Dense):
            # Count flops for Dense layer
            layer_flops_activation = layer.units

        flops_activation += layer_flops_activation

    return flops_activation

flops_activation = count_flops(model_1)
print("Number of FLOPs - Activation Functions: {:.2f}".format(flops_activation))
# Out:
# Number of FLOPs - Activation Functions: 51018.00

# %% [markdown]
# **BASE FUNCTION**

# %%
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

import tensorflow
tensorflow.random.set_seed(22)

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# from sparse label to categorical
num_labels = len(np.unique(y_train))
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# reshape and normalize input images
image_size = x_train.shape[1]
x_train = np.reshape(x_train,[-1, image_size, image_size, 1])
x_test = np.reshape(x_test,[-1, image_size, image_size, 1])
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# network parameters
input_shape = (image_size, image_size, 1)
batch_size = 128
kernel_size = 3
filters = 64
dropout = 0.3

# use functional API to build cnn layers
inputs = Input(shape=input_shape)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='sigmoid')(inputs)

y = MaxPooling2D()(y)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='sigmoid')(y)

y = MaxPooling2D()(y)
# y = Conv2D(filters=filters,
#            kernel_size=kernel_size,
#            activation='relu')(y)
# image to vector before connecting to dense layer
y = Flatten()(y)
# dropout regularization
#y = Dropout(dropout)(y)
outputs = Dense(num_labels, activation='softmax')(y)



# build the model by supplying inputs/outputs
model_3 = Model(inputs=inputs, outputs=outputs)
# network model in text
model_3.summary()
# Retrieve the config
import tensorflow
from tensorflow.keras.optimizers import Adam
# classifier loss, Adam optimizer, classifier accuracy
model_3.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.0001),
              metrics=['accuracy'])

import time

start_time = time.time()
# train the model with input images and labels
model_3.fit(x_train,
          y_train,
          validation_data=(x_test, y_test),
          epochs=50,
          batch_size=batch_size)
end_time = time.time()
execution_time = end_time - start_time

print("Execution time: {:.2f} seconds".format(execution_time))

# model accuracy on test dataset
score = model_3.evaluate(x_test,
                       y_test,
                       batch_size=batch_size,
                       verbose=0)
print("\nTest accuracy: %.1f%%" % (100.0 * score[1]))
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_6 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_10 (Conv2D)          (None, 26, 26, 64)        640
#
#  max_pooling2d_10 (MaxPoolin  (None, 13, 13, 64)       0
#  g2D)
#
#  conv2d_11 (Conv2D)          (None, 11, 11, 64)        36928
#
#  max_pooling2d_11 (MaxPoolin  (None, 5, 5, 64)         0
#  g2D)
#
#  flatten_5 (Flatten)         (None, 1600)              0
#
#  dense_5 (Dense)             (None, 10)                16010
#
# ...
# Total params: 53,578
# Trainable params: 53,578
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 3s 4ms/step - loss: 2.3036 - accuracy: 0.1187 - val_loss: 2.2803 - val_accuracy: 0.1406
# Epoch 2/50
# ...

# %%
def count_flops(model):
    flops = 0
    for layer in model.layers:
        layer_flops = 0
        if isinstance(layer, keras.layers.Conv2D):
            # Count flops for Conv2D layer
            kernel_flops = layer.kernel_size[0] * layer.kernel_size[1] * layer.input_shape[-1]
            output_size = np.prod(layer.output_shape[1:])
            layer_flops = kernel_flops * output_size
        elif isinstance(layer, keras.layers.Dense):
            # Count flops for Dense layer
            layer_flops = layer.input_shape[-1] * layer.units
        flops += layer_flops
    return flops

total_flops = count_flops(model_3)
print("Number of FLOPs: {:.2f}".format(total_flops))
# Out:
# Number of FLOPs: 4865920.00

# %%
def count_flops(model):
    flops_mul = 0
    flops_add = 0
    flops_div = 0
    flops_sub = 0

    for layer in model.layers:
        layer_flops_mul = 0
        layer_flops_add = 0
        layer_flops_div = 0
        layer_flops_sub = 0

        if isinstance(layer, keras.layers.Conv2D):
            # Count flops for Conv2D layer
            kernel_flops = layer.kernel_size[0] * layer.kernel_size[1] * layer.input_shape[-1]
            output_size = np.prod(layer.output_shape[1:])
            layer_flops_mul = kernel_flops * output_size
            layer_flops_add = (kernel_flops - 1) * output_size
        elif isinstance(layer, keras.layers.Dense):
            # Count flops for Dense layer
            layer_flops_mul = layer.input_shape[-1] * layer.units
            layer_flops_add = (layer.input_shape[-1] - 1) * layer.units

        flops_mul += layer_flops_mul
        flops_add += layer_flops_add
        flops_div += layer_flops_div
        flops_sub += layer_flops_sub

    return flops_mul, flops_add, flops_div, flops_sub

flops_mul, flops_add, flops_div, flops_sub = count_flops(model_3)
print("Number of FLOPs - Multiply: {:.2f}".format(flops_mul))
print("Number of FLOPs - Add: {:.2f}".format(flops_add))
print("Number of FLOPs - Divide: {:.2f}".format(flops_div))
print("Number of FLOPs - Subtract: {:.2f}".format(flops_sub))
# Out:
# Number of FLOPs - Multiply: 4865920.00
# Number of FLOPs - Add: 4814902.00
# Number of FLOPs - Divide: 0.00
# Number of FLOPs - Subtract: 0.00

# %%
def count_flops(model):
    flops_activation = 0

    for layer in model.layers:
        layer_flops_activation = 0

        if isinstance(layer, keras.layers.Conv2D):
            # Count flops for Conv2D layer
            kernel_flops = layer.kernel_size[0] * layer.kernel_size[1] * layer.input_shape[-1]
            output_size = np.prod(layer.output_shape[1:])
            layer_flops_activation = output_size
        elif isinstance(layer, keras.layers.Dense):
            # Count flops for Dense layer
            layer_flops_activation = layer.units

        flops_activation += layer_flops_activation

    return flops_activation

flops_activation = count_flops(model_3)
print("Number of FLOPs - Activation Functions: {:.2f}".format(flops_activation))
# Out:
# Number of FLOPs - Activation Functions: 51018.00
