# %%
# Imnporting Libraries
from keras.models import Sequential
from keras.layers import Dense
import tensorflow as tf

# Custom activation function
from keras.layers import Activation
from keras import backend as k
import tensorflow as tf
from tensorflow import keras
import keras.utils as generic_utils
import tensorflow.python.keras.utils as generic_utils
from tensorflow.keras.utils import get_custom_objects


@tf.function
def custom_activation(x):
  #def f1(): return k.tf.add(0.001,k.tf.add(x,7.5))
  def f3(): return k.tf.add(0.1935,k.tf.multiply(tf.cast(x, tf.float32),0.047))
  def f5(): return k.tf.add(0.3435,k.tf.multiply(tf.cast(x, tf.float32),0.107))
  def f7(): return k.tf.add(0.5,k.tf.multiply(tf.cast(x, tf.float32),0.231))
  def f9(): return k.tf.add(0.8065,k.tf.multiply(tf.cast(x, tf.float32),0.047))
  def f11(): return k.tf.add(0.908,k.tf.multiply(tf.cast(x, tf.float32),0.018))
  def f12(): return k.tf.ones([1,1],tf.float32)

  def f10(): return k.tf.where(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), 3), tf.less(tf.cast(x, tf.float32), 4)),x=f11(),y=f12())
  def f8(): return k.tf.where(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), 2), tf.less(tf.cast(x, tf.float32), 3)),x=f9(),y=f10())
  def f6(): return k.tf.where(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), -2), tf.less(tf.cast(x, tf.float32), 2)),x=f7(),y=f8())
  def f4(): return k.tf.where(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), -3), tf.less(tf.cast(x, tf.float32), -2)),x=f5(),y=f6())
  def f2(): return k.tf.where(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), -4), tf.less(tf.cast(x, tf.float32), -3)),x=f3(),y=f4())


  r = tf.where(
         condition=(k.tf.logical_and(k.tf.greater(tf.cast(x, tf.float32), -10), tf.less(tf.cast(x, tf.float32), -4))),
         x=k.tf.add(0.0085,k.tf.multiply(tf.cast(x, tf.float32),0.001)),
         y=f2()
     )

  return r

# 0
# 0.002 + 0.001(x+6.25) -> 0.00825+0.001x
# 0.023 + 0.007(x+3.75) -> 0.4925+0.007x
# 0.245 + 0.076(x+1.125) -> 0.3305+0.076x
# 0.755 + 0.207(x-1.125) -> 0.5222-0.207x
# 0.977 + 0.099(x-3.75) -> 0.6058-0.099x
# 0.998 + 0.012(x-6.25) -> 0.923-0.012x
# 1.0 + 0.001(x-8.75) -> 0.99125-0.001x

# k.tf.zeros([1,1], tf.float32)
"""
  r = K.tf.where(
         condition=(K.tf.logical_and(K.tf.greater(x, -10), K.tf.less(x, -5))),
         x=K.tf.add(0.001,K.tf.add(x,7.5)),
         y=f2()
     )
"""
#tf.logical_or((tf.logical_and(tf.greater(x, -10), tf.less(x, -5))), (tf.logical_and(tf.greater(x, -5), tf.less(x, 5)) )


    #def f1(): return tf.add(0.5,tf.multi(0.099,x))

    # return tf.where(
    #     condition=tf.logical_or((tf.logical_and(tf.greater(x, -10), tf.less(x, -5))), (tf.logical_and(tf.greater(x, -5), tf.less(x, 5)) )),
    #     x=tf.add(0.001,tf.add(x,7.5)),
    #     y=tf.add(0.5,tf.multiply(0.099,x))
    # )

"""
  x =tf.dtypes.cast(x, tf.int32)
  if (x > -10 & x < -5):
    y = 0.001 + 0.015*(x+7.5);
  if (x > -5 & x < 5):
    y = 0.5 + 0.099*x;
  if x > 5:
    y = 0.999;
  return y
"""
"""
loss = tf.where(
        condition=tf.logical_or((tf.logical_and(tf.greater(y_true, 0.0), tf.greater(y_pred, y_true))), (tf.logical_and(tf.less(y_true, 0.0), tf.less(y_pred, y_true)))),
        x=loss * penalty / 5,
        y=loss * penalty / 10
    )
"""
"""
# working
# tf.where(tf.less(x, 0), tf.add(0.5,tf.multiply(0.099,x)) ,tf.add(0.5,tf.multiply(0.099,x)))
"""
# tf.where(tf.less(x, 0), true_fn=lambda: tf.add(0.5,tf.multiply(0.099,x)), false_fn=lambda: tf.add(0.5,tf.multiply(0.099,x)))
# tf.cond(tf.logical_and(tf.less(x,-10),tf.greater(x,-5))):
"""
    if x > -5 and x < 5:
        return tf.add(0.5,tf.multi(0.099,x))
    if x > 5:
        return 0.999
"""
get_custom_objects().update({'custom_activation': Activation(custom_activation)})
"""
# Usage
model = Sequential()
model.add(Dense(32, input_dim=784))
model.add(Activation(custom_activation, name='SpecialActivation'))
print(model.summary())
"""
# Out:
# "\n# Usage\nmodel = Sequential()\nmodel.add(Dense(32, input_dim=784))\nmodel.add(Activation(custom_activation, name='SpecialActivation'))\nprint(model.summary())\n"

# %%
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

import tensorflow
tensorflow.random.set_seed(22)

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# from sparse label to categorical
num_labels = len(np.unique(y_train))
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# reshape and normalize input images
image_size = x_train.shape[1]
x_train = np.reshape(x_train,[-1, image_size, image_size, 1])
x_test = np.reshape(x_test,[-1, image_size, image_size, 1])
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# network parameters
input_shape = (image_size, image_size, 1)
batch_size = 128
kernel_size = 3
filters = 64
dropout = 0.3

# use functional API to build cnn layers
inputs = Input(shape=input_shape)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(inputs)

y = MaxPooling2D()(y)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(y)

y = MaxPooling2D()(y)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='custom_activation')(y)

y = MaxPooling2D()(y)
# y = Conv2D(filters=filters,
#            kernel_size=kernel_size,
#            activation='relu')(y)
# image to vector before connecting to dense layer
y = Flatten()(y)
# dropout regularization
#y = Dropout(dropout)(y)
outputs = Dense(num_labels, activation='softmax')(y)



# build the model by supplying inputs/outputs
model = Model(inputs=inputs, outputs=outputs)
# network model in text
model.summary()
# Retrieve the config
import tensorflow
from tensorflow.keras.optimizers import Adam
# classifier loss, Adam optimizer, classifier accuracy
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.0001),
              metrics=['accuracy'])

# train the model with input images and labels
model.fit(x_train,
          y_train,
          validation_data=(x_test, y_test),
          epochs=50,
          batch_size=batch_size)

# model accuracy on test dataset
score = model.evaluate(x_test,
                       y_test,
                       batch_size=batch_size,
                       verbose=0)
print("\nTest accuracy: %.1f%%" % (100.0 * score[1]))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 26, 26, 64)        640
#
#  max_pooling2d (MaxPooling2D  (None, 13, 13, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 64)          36928
#
#  max_pooling2d_2 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 64)                0
#
#  dense (Dense)               (None, 10)                650
#
# =================================================================
# Total params: 75,146
# Trainable params: 75,146
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 23s 21ms/step - loss: 2.3034 - accuracy: 0.1137 - val_loss: 2.2980 - val_accuracy: 0.1412
# Epoch 2/50
# 469/469 [==============================] - 9s 19ms/step - loss: 2.2809 - accuracy: 0.1802 - val_loss: 2.2293 - val_accuracy: 0.2567
# Epoch 3/50
# 469/469 [==============================] - 9s 20ms/step - loss: 1.9606 - accuracy: 0.4559 - val_loss: 1.5643 - val_accuracy: 0.6076
# Epoch 4/50
# 469/469 [==============================] - 9s 20ms/step - loss: 1.3282 - accuracy: 0.6636 - val_loss: 1.0996 - val_accuracy: 0.7360
# Epoch 5/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.9983 - accuracy: 0.7557 - val_loss: 0.8543 - val_accuracy: 0.8030
# Epoch 6/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.8005 - accuracy: 0.8061 - val_loss: 0.6953 - val_accuracy: 0.8389
# Epoch 7/50
# 469/469 [==============================] - 9s 19ms/step - loss: 0.6626 - accuracy: 0.8408 - val_loss: 0.5824 - val_accuracy: 0.8630
# Epoch 8/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.5584 - accuracy: 0.8663 - val_loss: 0.4923 - val_accuracy: 0.8858
# Epoch 9/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.4776 - accuracy: 0.8853 - val_loss: 0.4240 - val_accuracy: 0.8965
# Epoch 10/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.4154 - accuracy: 0.8994 - val_loss: 0.3723 - val_accuracy: 0.9096
# Epoch 11/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.3672 - accuracy: 0.9107 - val_loss: 0.3311 - val_accuracy: 0.9176
# Epoch 12/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.3292 - accuracy: 0.9189 - val_loss: 0.2982 - val_accuracy: 0.9257
# Epoch 13/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.2985 - accuracy: 0.9252 - val_loss: 0.2693 - val_accuracy: 0.9314
# Epoch 14/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.2731 - accuracy: 0.9306 - val_loss: 0.2479 - val_accuracy: 0.9369
# Epoch 15/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.2520 - accuracy: 0.9354 - val_loss: 0.2327 - val_accuracy: 0.9388
# Epoch 16/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.2346 - accuracy: 0.9393 - val_loss: 0.2157 - val_accuracy: 0.9440
# Epoch 17/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.2194 - accuracy: 0.9422 - val_loss: 0.2020 - val_accuracy: 0.9452
# Epoch 18/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.2067 - accuracy: 0.9452 - val_loss: 0.1922 - val_accuracy: 0.9483
# Epoch 19/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1955 - accuracy: 0.9476 - val_loss: 0.1809 - val_accuracy: 0.9513
# Epoch 20/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1858 - accuracy: 0.9499 - val_loss: 0.1732 - val_accuracy: 0.9527
# Epoch 21/50
# 469/469 [==============================] - 10s 21ms/step - loss: 0.1769 - accuracy: 0.9517 - val_loss: 0.1669 - val_accuracy: 0.9539
# Epoch 22/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1690 - accuracy: 0.9536 - val_loss: 0.1589 - val_accuracy: 0.9560
# Epoch 23/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1618 - accuracy: 0.9550 - val_loss: 0.1540 - val_accuracy: 0.9569
# Epoch 24/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1555 - accuracy: 0.9575 - val_loss: 0.1478 - val_accuracy: 0.9594
# Epoch 25/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1501 - accuracy: 0.9585 - val_loss: 0.1413 - val_accuracy: 0.9616
# Epoch 26/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1452 - accuracy: 0.9602 - val_loss: 0.1383 - val_accuracy: 0.9606
# Epoch 27/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1398 - accuracy: 0.9614 - val_loss: 0.1330 - val_accuracy: 0.9621
# Epoch 28/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1356 - accuracy: 0.9630 - val_loss: 0.1296 - val_accuracy: 0.9642
# Epoch 29/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1320 - accuracy: 0.9628 - val_loss: 0.1285 - val_accuracy: 0.9634
# Epoch 30/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1283 - accuracy: 0.9641 - val_loss: 0.1239 - val_accuracy: 0.9648
# Epoch 31/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1252 - accuracy: 0.9649 - val_loss: 0.1201 - val_accuracy: 0.9659
# Epoch 32/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1213 - accuracy: 0.9660 - val_loss: 0.1181 - val_accuracy: 0.9668
# Epoch 33/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1191 - accuracy: 0.9667 - val_loss: 0.1156 - val_accuracy: 0.9674
# Epoch 34/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1163 - accuracy: 0.9673 - val_loss: 0.1130 - val_accuracy: 0.9683
# Epoch 35/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1133 - accuracy: 0.9681 - val_loss: 0.1125 - val_accuracy: 0.9692
# Epoch 36/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1111 - accuracy: 0.9688 - val_loss: 0.1096 - val_accuracy: 0.9694
# Epoch 37/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1088 - accuracy: 0.9696 - val_loss: 0.1070 - val_accuracy: 0.9702
# Epoch 38/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1065 - accuracy: 0.9696 - val_loss: 0.1056 - val_accuracy: 0.9698
# Epoch 39/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1043 - accuracy: 0.9708 - val_loss: 0.1045 - val_accuracy: 0.9708
# Epoch 40/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1024 - accuracy: 0.9711 - val_loss: 0.1039 - val_accuracy: 0.9714
# Epoch 41/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.1004 - accuracy: 0.9716 - val_loss: 0.1005 - val_accuracy: 0.9706
# Epoch 42/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0984 - accuracy: 0.9724 - val_loss: 0.1012 - val_accuracy: 0.9716
# Epoch 43/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0971 - accuracy: 0.9726 - val_loss: 0.0998 - val_accuracy: 0.9710
# Epoch 44/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0948 - accuracy: 0.9732 - val_loss: 0.0966 - val_accuracy: 0.9727
# Epoch 45/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0937 - accuracy: 0.9738 - val_loss: 0.0971 - val_accuracy: 0.9719
# Epoch 46/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0918 - accuracy: 0.9744 - val_loss: 0.0949 - val_accuracy: 0.9728
# Epoch 47/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0908 - accuracy: 0.9741 - val_loss: 0.0950 - val_accuracy: 0.9722
# Epoch 48/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0884 - accuracy: 0.9753 - val_loss: 0.0919 - val_accuracy: 0.9743
# Epoch 49/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0871 - accuracy: 0.9753 - val_loss: 0.0920 - val_accuracy: 0.9731
# Epoch 50/50
# 469/469 [==============================] - 9s 20ms/step - loss: 0.0859 - accuracy: 0.9756 - val_loss: 0.0912 - val_accuracy: 0.9744
#
# Test accuracy: 97.4%

# %%
import numpy as np
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical

import tensorflow
tensorflow.random.set_seed(22)

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# from sparse label to categorical
num_labels = len(np.unique(y_train))
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# reshape and normalize input images
image_size = x_train.shape[1]
x_train = np.reshape(x_train,[-1, image_size, image_size, 1])
x_test = np.reshape(x_test,[-1, image_size, image_size, 1])
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# network parameters
input_shape = (image_size, image_size, 1)
batch_size = 128
kernel_size = 3
filters = 64
dropout = 0.3

# use functional API to build cnn layers
inputs = Input(shape=input_shape)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='sigmoid')(inputs)

y = MaxPooling2D()(y)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='sigmoid')(y)

y = MaxPooling2D()(y)

y = Conv2D(filters=filters,
           kernel_size=kernel_size,
           activation='sigmoid')(y)

y = MaxPooling2D()(y)
# y = Conv2D(filters=filters,
#            kernel_size=kernel_size,
#            activation='relu')(y)
# image to vector before connecting to dense layer
y = Flatten()(y)
# dropout regularization
#y = Dropout(dropout)(y)
outputs = Dense(num_labels, activation='softmax')(y)



# build the model by supplying inputs/outputs
model = Model(inputs=inputs, outputs=outputs)
# network model in text
model.summary()
# Retrieve the config
import tensorflow
from tensorflow.keras.optimizers import Adam
# classifier loss, Adam optimizer, classifier accuracy
model.compile(loss='categorical_crossentropy',
              optimizer=Adam(learning_rate=0.0001),
              metrics=['accuracy'])

# train the model with input images and labels
model.fit(x_train,
          y_train,
          validation_data=(x_test, y_test),
          epochs=50,
          batch_size=batch_size)

# model accuracy on test dataset
score = model.evaluate(x_test,
                       y_test,
                       batch_size=batch_size,
                       verbose=0)
print("\nTest accuracy: %.1f%%" % (100.0 * score[1]))
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 28, 28, 1)]       0
#
#  conv2d_3 (Conv2D)           (None, 26, 26, 64)        640
#
#  max_pooling2d_3 (MaxPooling  (None, 13, 13, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 11, 11, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 5, 5, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 64)          36928
#
#  max_pooling2d_5 (MaxPooling  (None, 1, 1, 64)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 75,146
# Trainable params: 75,146
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 469/469 [==============================] - 4s 6ms/step - loss: 2.3040 - accuracy: 0.1104 - val_loss: 2.2996 - val_accuracy: 0.1135
# Epoch 2/50
# 469/469 [==============================] - 3s 6ms/step - loss: 2.2930 - accuracy: 0.1368 - val_loss: 2.2731 - val_accuracy: 0.1880
# Epoch 3/50
# 469/469 [==============================] - 3s 6ms/step - loss: 2.1166 - accuracy: 0.3976 - val_loss: 1.7922 - val_accuracy: 0.6422
# Epoch 4/50
# 469/469 [==============================] - 3s 6ms/step - loss: 1.4624 - accuracy: 0.6965 - val_loss: 1.1717 - val_accuracy: 0.7620
# Epoch 5/50
# 469/469 [==============================] - 3s 6ms/step - loss: 1.0285 - accuracy: 0.7824 - val_loss: 0.8596 - val_accuracy: 0.8228
# Epoch 6/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.7894 - accuracy: 0.8296 - val_loss: 0.6736 - val_accuracy: 0.8566
# Epoch 7/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.6368 - accuracy: 0.8598 - val_loss: 0.5526 - val_accuracy: 0.8782
# Epoch 8/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.5324 - accuracy: 0.8785 - val_loss: 0.4672 - val_accuracy: 0.8922
# Epoch 9/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4577 - accuracy: 0.8927 - val_loss: 0.4041 - val_accuracy: 0.9025
# Epoch 10/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.4016 - accuracy: 0.9036 - val_loss: 0.3580 - val_accuracy: 0.9151
# Epoch 11/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3582 - accuracy: 0.9121 - val_loss: 0.3197 - val_accuracy: 0.9210
# Epoch 12/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.3232 - accuracy: 0.9198 - val_loss: 0.2913 - val_accuracy: 0.9263
# Epoch 13/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2949 - accuracy: 0.9257 - val_loss: 0.2651 - val_accuracy: 0.9318
# Epoch 14/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2712 - accuracy: 0.9305 - val_loss: 0.2451 - val_accuracy: 0.9358
# Epoch 15/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2513 - accuracy: 0.9351 - val_loss: 0.2291 - val_accuracy: 0.9393
# Epoch 16/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2346 - accuracy: 0.9383 - val_loss: 0.2133 - val_accuracy: 0.9424
# Epoch 17/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2200 - accuracy: 0.9415 - val_loss: 0.2020 - val_accuracy: 0.9460
# Epoch 18/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.2073 - accuracy: 0.9448 - val_loss: 0.1897 - val_accuracy: 0.9478
# Epoch 19/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1964 - accuracy: 0.9467 - val_loss: 0.1802 - val_accuracy: 0.9499
# Epoch 20/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1865 - accuracy: 0.9490 - val_loss: 0.1715 - val_accuracy: 0.9520
# Epoch 21/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1779 - accuracy: 0.9511 - val_loss: 0.1649 - val_accuracy: 0.9532
# Epoch 22/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1700 - accuracy: 0.9526 - val_loss: 0.1581 - val_accuracy: 0.9556
# Epoch 23/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1627 - accuracy: 0.9548 - val_loss: 0.1519 - val_accuracy: 0.9567
# Epoch 24/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1564 - accuracy: 0.9563 - val_loss: 0.1461 - val_accuracy: 0.9569
# Epoch 25/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1504 - accuracy: 0.9577 - val_loss: 0.1405 - val_accuracy: 0.9586
# Epoch 26/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1449 - accuracy: 0.9598 - val_loss: 0.1363 - val_accuracy: 0.9595
# Epoch 27/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1396 - accuracy: 0.9605 - val_loss: 0.1327 - val_accuracy: 0.9608
# Epoch 28/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1350 - accuracy: 0.9618 - val_loss: 0.1278 - val_accuracy: 0.9617
# Epoch 29/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1308 - accuracy: 0.9625 - val_loss: 0.1248 - val_accuracy: 0.9624
# Epoch 30/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1266 - accuracy: 0.9644 - val_loss: 0.1204 - val_accuracy: 0.9639
# Epoch 31/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1229 - accuracy: 0.9651 - val_loss: 0.1176 - val_accuracy: 0.9650
# Epoch 32/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1193 - accuracy: 0.9663 - val_loss: 0.1143 - val_accuracy: 0.9657
# Epoch 33/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1160 - accuracy: 0.9672 - val_loss: 0.1113 - val_accuracy: 0.9662
# Epoch 34/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1129 - accuracy: 0.9682 - val_loss: 0.1089 - val_accuracy: 0.9661
# Epoch 35/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1098 - accuracy: 0.9691 - val_loss: 0.1065 - val_accuracy: 0.9668
# Epoch 36/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1068 - accuracy: 0.9696 - val_loss: 0.1051 - val_accuracy: 0.9685
# Epoch 37/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1043 - accuracy: 0.9708 - val_loss: 0.1013 - val_accuracy: 0.9697
# Epoch 38/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.1017 - accuracy: 0.9714 - val_loss: 0.1009 - val_accuracy: 0.9686
# Epoch 39/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0995 - accuracy: 0.9722 - val_loss: 0.0979 - val_accuracy: 0.9699
# Epoch 40/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0972 - accuracy: 0.9725 - val_loss: 0.0962 - val_accuracy: 0.9698
# Epoch 41/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0948 - accuracy: 0.9736 - val_loss: 0.0947 - val_accuracy: 0.9714
# Epoch 42/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0926 - accuracy: 0.9742 - val_loss: 0.0924 - val_accuracy: 0.9727
# Epoch 43/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0907 - accuracy: 0.9746 - val_loss: 0.0911 - val_accuracy: 0.9720
# Epoch 44/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0888 - accuracy: 0.9755 - val_loss: 0.0887 - val_accuracy: 0.9730
# Epoch 45/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0869 - accuracy: 0.9755 - val_loss: 0.0884 - val_accuracy: 0.9725
# Epoch 46/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0850 - accuracy: 0.9766 - val_loss: 0.0862 - val_accuracy: 0.9732
# Epoch 47/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0833 - accuracy: 0.9767 - val_loss: 0.0845 - val_accuracy: 0.9736
# Epoch 48/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0817 - accuracy: 0.9771 - val_loss: 0.0833 - val_accuracy: 0.9746
# Epoch 49/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0803 - accuracy: 0.9774 - val_loss: 0.0830 - val_accuracy: 0.9741
# Epoch 50/50
# 469/469 [==============================] - 3s 6ms/step - loss: 0.0786 - accuracy: 0.9782 - val_loss: 0.0811 - val_accuracy: 0.9754
#
# Test accuracy: 97.5%
